# %% [markdown]
# # Data Cleaning with R
#
# This notebook demonstrates data cleaning principles in R. First we take a look at some encoding issues using a contrived example, and then we work through an example of loading some data as published on the Open Data portal.
#
# - [Part 1: Encoding Issues](#Encoding-Issues)
# - [Part 2: Example: Open Data](#Example:-Open-Data)

# %%
library(readr)
library(stringr)
library(dplyr)
library(tidyr)
# Out:
# Attaching package: 'dplyr'
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union

# %% [markdown]
# # Encoding Issues
# Computers ultimately represent everything as a number, and over time, different operating systems, and different languages there have been many ways of representing text. Most encodings (except for ones designed specifically for Asian languages) are extensions of ASCII, which was designed for English, so the English alphabet and most common punctuation characters are usually not a problem, but ASCII does not include things like accented characters for French.
#
# To demonstrate some of the potential issues, I made a file in Notepad and saved it using the default ANSI encoding (this default is changing to UTF8 as of the May 2019 update of Windows 10). This shows French text with accents, and non-ASCII punctuation characters. This formatting is similar to Excel's settings when used in French to generate a CSV file - it uses a ; instead of , for the delimiter as , is the decimal separator.
#
# ```
# DEPARTEMENT;DÉPENSES;Punctuation
# Administration du pipe-line du Nord;123456,88;“–”
# Agence canadienne d’évaluation environnementale;999999,24;†•
# Agence de développement économique du Canada pour les régions du Québec;234567,00;€
# ```
#
# ### Base R
# Base R says it supports latin1 or UTF-8, with the note that control characters are interptreted as per Windows-1252 on some systems and particularly since R 3.5.0. In addition to `read.csv` and `read.delim` (for more control), R provides `read.csv2` to handle the European style CSVs with ; as the delimiter. This function does exactly what we want for this file by default.

# %%
read.csv2('data/NotepadFrench.csv')
# Out:
# Warning message in read.table(file = file, header = header, sep = sep, quote = quote, :
# "incomplete final line found by readTableHeader on 'NotepadFrench.csv'"
#   DEPARTEMENT
# 1 Administration du pipe-line du Nord
# 2 Agence canadienne dévaluation environnementale
# 3 Agence de développement économique du Canada pour les régions du Québec
#   DÉPENSES Punctuation
# 1 123456.9 
# 2 999999.2 
# 3 234567.0 

# %% [markdown]
# ## Readr package from Tidyverse
# The Tidyverse is a popular set of R packages which include improvements to the Base R packages. Readr reads files into a 'tibble' rather than a data.frame, and it defaults to UTF-8. A cheat sheet for readr and tibble can be found here: https://rawgit.com/rstudio/cheatsheets/master/data-import.pdf
#
# ## Issue 1: Can't read the file at all with invalid UTF-8
#
# In many cases, just calling read_csv will work, but not in this one.

# %%
read_csv('data/NotepadFrench.csv')
# Out:
# Parsed with column specification:
# cols(
#   `DEPARTEMENT;D<c9>PENSES;Punctuation` = col_character()
# )
# Warning message in rbind(names(probs), probs_f):
# "number of columns of result is not a multiple of vector length (arg 1)"Warning message:
# "3 parsing failures.
# row # A tibble: 3 x 5 col     row col   expected  actual    file                expected   <int> <chr> <chr>     <chr>     <chr>               actual 1     1 <NA>  1 columns 2 columns 'NotepadFrench.csv' file 2     2 <NA>  1 columns 2 columns 'NotepadFrench.csv' row 3     3 <NA>  1 columns 2 columns 'NotepadFrench.csv'
# "Warning message in FUN(X[[i]], ...):
# "input string 1 is invalid UTF-8"Warning message in FUN(X[[i]], ...):
# "input string 1 is invalid UTF-8"Warning message in FUN(X[[i]], ...):
# "input string 1 is invalid UTF-8"Warning message in FUN(X[[i]], ...):
# "input string 1 is invalid UTF-8"Warning message in FUN(X[[i]], ...):
# "input string 1 is invalid UTF-8"Warning message in FUN(X[[i]], ...):
# "input string 1 is invalid UTF-8"Warning message in FUN(X[[i]], ...):
# "input string 1 is invalid UTF-8"Warning message in FUN(X[[i]], ...):
# "input string 1 is invalid UTF-8"Warning message in FUN(X[[i]], ...):
# "input string 1 is invalid UTF-8"Warning message in FUN(X[[i]], ...):
# "input string 1 is invalid UTF-8"Warning message in FUN(X[[i]], ...):
# "input string 1 is invalid UTF-8"Warning message in FUN(X[[i]], ...):
# "input string 1 is invalid UTF-8"Warning message in FUN(X[[i]], ...):
# "input string 1 is invalid UTF-8"Warning message in FUN(X[[i]], ...):
# "input string 1 is invalid UTF-8"Warning message in FUN(X[[i]], ...):
# "input string 1 is invalid UTF-8"Warning message in FUN(X[[i]], ...):
# "input string 1 is invalid UTF-8"ERROR while rich displaying an object: Error in gsub(" &\\", "\\", r, fixed = TRUE): input string 1 is invalid UTF-8
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     rpr <- mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     rpr <- mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. mime2repr[[mime]](obj)
# 8. repr_latex.data.frame(obj)
# 9. gsub(" &\\", "\\", r, fixed = TRUE)

# %% [markdown]
# In order to set the encoding for Readr, we need to create a [locale](https://readr.tidyverse.org/reference/locale.html). We also switch to using `read_csv2` which deals with the European style CSV with ; as the separator and , as the decimal. `read_delim` is another option providing more control.
#
# ## Issue 2: Not all characters loaded properly - character codes and mojibake
# `latin-1` (also known as `ISO-8859-1`) is a common encoding for Western European text including French, but it doesn't include the punctuation characters. Here R is showing the punctuation haracters as strings like <U+0093>. Note that Readr doesn't use the same flexible definition of latin1 as the built in read.csv.

# %%
no_punctuation = read_csv2('data/NotepadFrench.csv', locale=locale(encoding="latin1"))
no_punctuation
# Out:
# Using ',' as decimal and '.' as grouping mark. Use read_delim() for more control.
# Parsed with column specification:
# cols(
#   DEPARTEMENT = col_character(),
#   DÉPENSES = col_double(),
#   Punctuation = col_character()
# )
#   DEPARTEMENT
# 1 Administration du pipe-line du Nord
# 2 Agence canadienne d<U+0092>évaluation environnementale
# 3 Agence de développement économique du Canada pour les régions du Québec
#   DÉPENSES Punctuation
# 1 123456.9 <U+0093><U+0096><U+0094>
# 2 999999.2 <U+0086><U+0095>
# 3 234567.0 <U+0080>

# %% [markdown]
# Another possibility is that characters map to incorrect visible characters. Here we attempt to load it using IBM863, 'MS-DOS French Canada', which was used by MS-DOS systems in Canada. This also demonstrates using `read_delim` for the same results as `read_csv2`.

# %%
read_delim('data/NotepadFrench.csv', ";", locale=locale(encoding="IBM863", decimal=","))
# Out:
# Parsed with column specification:
# cols(
#   DEPARTEMENT = col_character(),
#   `D+PENSES` = col_double(),
#   Punctuation = col_character()
# )
#   DEPARTEMENT
# 1 Administration du pipe-line du Nord
# 2 Agence canadienne dÊTvaluation environnementale
# 3 Agence de dTveloppement Tconomique du Canada pour les rTgions du QuTbec
#   D+PENSES Punctuation
# 1 123456.9 ôûË
# 2 999999.2 ¶Ï
# 3 234567.0 Ç

# %% [markdown]
# `windows-1252` is a Windows specific superset of `ISO-8859-1` which includes several additional characters. It is one of several different 'ANSI Codepages' for representing different languages. This is the most likely option if a file was created on a Windows system in English, French, or most Western European languages. Here I'm using `read_delim` without setting the decimal option to demonstrate what happens in R.

# %%
wrong_decimal = read_delim('data/NotepadFrench.csv', ";", locale=locale(encoding="windows-1252"))
wrong_decimal
# Out:
# Parsed with column specification:
# cols(
#   DEPARTEMENT = col_character(),
#   DÉPENSES = col_number(),
#   Punctuation = col_character()
# )
#   DEPARTEMENT
# 1 Administration du pipe-line du Nord
# 2 Agence canadienne dévaluation environnementale
# 3 Agence de développement économique du Canada pour les régions du Québec
#   DÉPENSES Punctuation
# 1 12345688 
# 2 99999924 
# 3 23456700 

# %% [markdown]
# While not strictly an encoding issue, one other issue with dealing with multiple languages is different localization settings like date formats and decimal separators. Here, ',' is being treated as a thousands separator not a decimal - unlike in Python it did read it as a number, but not the right number! This can be set by using read_csv2, or passing in parameters to the locale.

# %%
sum(wrong_decimal["DÉPENSES"])
# Out:
# [1] 135802312

# %%
correct_sample = read_csv2('data/NotepadFrench.csv', locale=locale(encoding="windows-1252"))
correct_sample
# Out:
# Using ',' as decimal and '.' as grouping mark. Use read_delim() for more control.
# Parsed with column specification:
# cols(
#   DEPARTEMENT = col_character(),
#   DÉPENSES = col_double(),
#   Punctuation = col_character()
# )
#   DEPARTEMENT
# 1 Administration du pipe-line du Nord
# 2 Agence canadienne dévaluation environnementale
# 3 Agence de développement économique du Canada pour les régions du Québec
#   DÉPENSES Punctuation
# 1 123456.9 
# 2 999999.2 
# 3 234567.0 

# %%
sum(correct_sample["DÉPENSES"])
# Out:
# [1] 1358023

# %% [markdown]
# Here we save a version of the file which plays nicely with Readr defaults.

# %%
write.csv(correct_sample, 'data/utf8FrenchR.csv', fileEncoding='utf8', row.names=FALSE)
read_csv('data/utf8FrenchR.csv')
# Out:
# Parsed with column specification:
# cols(
#   DEPARTEMENT = col_character(),
#   DÉPENSES = col_double(),
#   Punctuation = col_character()
# )
#   DEPARTEMENT
# 1 Administration du pipe-line du Nord
# 2 Agence canadienne dévaluation environnementale
# 3 Agence de développement économique du Canada pour les régions du Québec
#   DÉPENSES Punctuation
# 1 123456.9 
# 2 999999.2 
# 3 234567.0 

# %% [markdown]
# ## Issue 3: Loading UTF8 into Excel
#
# Excel defaults to the ANSI codepage used by the operating system (e.g. Windows-1252), and will not properly load UTF8 text via File->Open.
#
# The solution is to import the text into Excel instead and choose the appropriate encoding.
# ![Loading UTF8 into Excel using Text Import](ExcelImport.png)

# %% [markdown]
# # Example: Open Data
# Fuel consumption ratings (NRCAN): https://open.canada.ca/data/en/dataset/98f1a129-f628-4ce4-b24d-6f16bf24dd64
#
# In this scenario, I want to do some analysis on a dataset published to the open data portal. This dataset is spread over multiple files for different years, and there are some minor changes to the columns over time. Like many datasets on Open Data it has some features which make it easier for people to look at but harder for machines - the column names are formatted over two rows, and there is some extra descriptions of fields below the main data section. A bit more unusually, it also has extra blank lines between rows and for some years, there are lots of extra blank columns and rows at the end.
#
# The Python version of this notebook has a functions which downloads the files, here we just read in.

# %%
en_consumption_files = list.files(pattern="downloads/MY[0-9]{4} Fuel Consumption Ratings.*csv")
en_consumption_files
# Out:
# character(0)

# %% [markdown]
# ## Cleaning up just the most recent year step by step
# In this section, I go through the steps to look at and fix issues with one file.

# %%
data = read_csv("downloads/MY2019 Fuel Consumption Ratings.csv")
head(data)
# Out:
# Warning message:
# "Missing column names filled in: 'X10' [10], 'X11' [11], 'X12' [12], 'X16' [16], 'X17' [17], 'X18' [18], 'X19' [19], 'X20' [20], 'X21' [21], 'X22' [22], 'X23' [23], 'X24' [24], 'X25' [25], 'X26' [26], 'X27' [27], 'X28' [28], 'X29' [29], 'X30' [30], 'X31' [31], 'X32' [32], 'X33' [33], 'X34' [34], 'X35' [35], 'X36' [36], 'X37' [37], 'X38' [38], 'X39' [39], 'X40' [40], 'X41' [41], 'X42' [42], 'X43' [43], 'X44' [44], 'X45' [45], 'X46' [46], 'X47' [47], 'X48' [48], 'X49' [49], 'X50' [50], 'X51' [51], 'X52' [52], 'X53' [53], 'X54' [54], 'X55' [55], 'X56' [56], 'X57' [57], 'X58' [58], 'X59' [59], 'X60' [60], 'X61' [61], 'X62' [62], 'X63' [63], 'X64' [64], 'X65' [65], 'X66' [66], 'X67' [67], 'X68' [68], 'X69' [69], 'X70' [70], 'X71' [71], 'X72' [72], 'X73' [73], 'X74' [74], 'X75' [75], 'X76' [76], 'X77' [77], 'X78' [78], 'X79' [79], 'X80' [80], 'X81' [81], 'X82' [82], 'X83' [83], 'X84' [84], 'X85' [85], 'X86' [86], 'X87' [87], 'X88' [88], 'X89' [89], 'X90' [90], 'X91' [91], 'X92' [92], 'X93' [93], 'X94' [94], 'X95' [95], 'X96' [96], 'X97' [97], 'X98' [98], 'X99' [99], 'X100' [100], 'X101' [101], 'X102' [102], 'X103' [103], 'X104' [104], 'X105' [105], 'X106' [106], 'X107' [107], 'X108' [108], 'X109' [109], 'X110' [110], 'X111' [111], 'X112' [112], 'X113' [113], 'X114' [114], 'X115' [115], 'X116' [116], 'X117' [117], 'X118' [118], 'X119' [119], 'X120' [120], 'X121' [121], 'X122' [122], 'X123' [123], 'X124' [124], 'X125' [125], 'X126' [126], 'X127' [127], 'X128' [128], 'X129' [129], 'X130' [130], 'X131' [131], 'X132' [132], 'X133' [133], 'X134' [134], 'X135' [135], 'X136' [136], 'X137' [137], 'X138' [138], 'X139' [139], 'X140' [140], 'X141' [141], 'X142' [142], 'X143' [143], 'X144' [144], 'X145' [145], 'X146' [146], 'X147' [147], 'X148' [148], 'X149' [149], 'X150' [150], 'X151' [151], 'X152' [152], 'X153' [153], 'X154' [154], 'X155' [155], 'X156' [156], 'X157' [157], 'X158' [158], 'X159' [159], 'X160' [160], 'X161' [161], 'X162' [162], 'X163' [163], 'X164' [164], 'X165' [165], 'X166' [166], 'X167' [167], 'X168' [168], 'X169' [169], 'X170' [170], 'X171' [171], 'X172' [172], 'X173' [173], 'X174' [174], 'X175' [175], 'X176' [176], 'X177' [177], 'X178' [178], 'X179' [179], 'X180' [180], 'X181' [181], 'X182' [182], 'X183' [183], 'X184' [184], 'X185' [185], 'X186' [186], 'X187' [187], 'X188' [188], 'X189' [189], 'X190' [190], 'X191' [191], 'X192' [192], 'X193' [193], 'X194' [194], 'X195' [195], 'X196' [196], 'X197' [197], 'X198' [198], 'X199' [199], 'X200' [200], 'X201' [201], 'X202' [202], 'X203' [203], 'X204' [204], 'X205' [205], 'X206' [206], 'X207' [207], 'X208' [208], 'X209' [209], 'X210' [210], 'X211' [211], 'X212' [212], 'X213' [213], 'X214' [214], 'X215' [215], 'X216' [216], 'X217' [217], 'X218' [218], 'X219' [219], 'X220' [220], 'X221' [221]"Warning message:
# "Duplicated column names deduplicated: 'Model' => 'Model_1' [3]"Parsed with column specification:
# cols(
#   .default = col_character(),
#   Cylinders = col_integer()
# )
# See spec(...) for full column specifications.
#   Model Make  Model_1           Vehicle Class Engine Size Cylinders
# 1 Year  NA    NA                NA            (L)         NA
# 2 2019  Acura ILX               Compact       2.4          4
# 3 2019  Acura MDX SH-AWD        SUV: Small    3.5          6
# 4 2019  Acura MDX SH-AWD A-SPEC SUV: Small    3.5          6
# 5 2019  Acura MDX Hybrid AWD    SUV: Small    3.0          6
# 6 2019  Acura NSX               Two-seater    3.5          6
#   Transmission Fuel Fuel Consumption X10            ... X212 X213 X214 X215
# 1 NA           Type City (L/100 km)  Hwy (L/100 km) ... NA   NA   NA   NA
# 2 AM8          Z    9.9              7.0            ... NA   NA   NA   NA
# 3 AS9          Z    12.2             9.0            ... NA   NA   NA   NA
# 4 AS9          Z    12.2             9.5            ... NA   NA   NA   NA
# 5 AM7          Z    9.1              9.0            ... NA   NA   NA   NA
# 6 AM9          Z    11.1             10.8           ... NA   NA   NA   NA
#   X216 X217 X218 X219 X220 X221
# 1 NA   NA   NA   NA   NA   NA
# 2 NA   NA   NA   NA   NA   NA
# 3 NA   NA   NA   NA   NA   NA
# 4 NA   NA   NA   NA   NA   NA
# 5 NA   NA   NA   NA   NA   NA
# 6 NA   NA   NA   NA   NA   NA

# %%
tail(data)
# Out:
#   Model Make Model_1 Vehicle Class Engine Size Cylinders Transmission Fuel
# 1 NA    NA   NA      NA            NA          NA        NA           NA
# 2 NA    NA   NA      NA            NA          NA        NA           NA
# 3 NA    NA   NA      NA            NA          NA        NA           NA
# 4 NA    NA   NA      NA            NA          NA        NA           NA
# 5 NA    NA   NA      NA            NA          NA        NA           NA
# 6 NA    NA   NA      NA            NA          NA        NA           NA
#   Fuel Consumption X10 ... X212 X213 X214 X215 X216 X217 X218 X219 X220 X221
# 1 NA               NA  ... NA   NA   NA   NA   NA   NA   NA   NA   NA   NA
# 2 NA               NA  ... NA   NA   NA   NA   NA   NA   NA   NA   NA   NA
# 3 NA               NA  ... NA   NA   NA   NA   NA   NA   NA   NA   NA   NA
# 4 NA               NA  ... NA   NA   NA   NA   NA   NA   NA   NA   NA   NA
# 5 NA               NA  ... NA   NA   NA   NA   NA   NA   NA   NA   NA   NA
# 6 NA               NA  ... NA   NA   NA   NA   NA   NA   NA   NA   NA   NA

# %% [markdown]
# Looking at the top and the bottom of the file, I see that there are a lot of columns that look to be empty, and also a lot of empty rows at the bottom.
#
# ### Identify and drop the extra columns
# Select all columns that have any values that aren't NA

# %%
data = data %>% select_if(function(x) any(!is.na(x)))
head(data)
# Out:
#   Model Make  Model_1           Vehicle Class Engine Size Cylinders
# 1 Year  NA    NA                NA            (L)         NA
# 2 2019  Acura ILX               Compact       2.4          4
# 3 2019  Acura MDX SH-AWD        SUV: Small    3.5          6
# 4 2019  Acura MDX SH-AWD A-SPEC SUV: Small    3.5          6
# 5 2019  Acura MDX Hybrid AWD    SUV: Small    3.0          6
# 6 2019  Acura NSX               Two-seater    3.5          6
#   Transmission Fuel Fuel Consumption X10            X11             X12
# 1 NA           Type City (L/100 km)  Hwy (L/100 km) Comb (L/100 km) Comb (mpg)
# 2 AM8          Z    9.9              7.0            8.6             33
# 3 AS9          Z    12.2             9.0            10.8            26
# 4 AS9          Z    12.2             9.5            11.0            26
# 5 AM7          Z    9.1              9.0            9.0             31
# 6 AM9          Z    11.1             10.8           11.0            26
#   CO2 Emissions CO2    Smog
# 1 (g/km)        Rating Rating
# 2 199           6      3
# 3 252           4      3
# 4 258           4      3
# 5 210           5      3
# 6 261           4      3

# %%
str(data)
# Out:
# Classes 'tbl_df', 'tbl' and 'data.frame':	1283 obs. of  15 variables:
#  $ Model           : chr  "Year" "2019" "2019" "2019" ...
#  $ Make            : chr  NA "Acura" "Acura" "Acura" ...
#  $ Model_1         : chr  NA "ILX" "MDX SH-AWD" "MDX SH-AWD A-SPEC" ...
#  $ Vehicle Class   : chr  NA "Compact" "SUV: Small" "SUV: Small" ...
#  $ Engine Size     : chr  "(L)" "2.4" "3.5" "3.5" ...
#  $ Cylinders       : int  NA 4 6 6 6 6 4 4 6 4 ...
#  $ Transmission    : chr  NA "AM8" "AS9" "AS9" ...
#  $ Fuel            : chr  "Type" "Z" "Z" "Z" ...
#  $ Fuel Consumption: chr  "City (L/100 km)" "9.9" "12.2" "12.2" ...
#  $ X10             : chr  "Hwy (L/100 km)" "7.0" "9.0" "9.5" ...
#  $ X11             : chr  "Comb (L/100 km)" "8.6" "10.8" "11.0" ...
#  $ X12             : chr  "Comb (mpg)" "33" "26" "26" ...
#  $ CO2 Emissions   : chr  "(g/km)" "199" "252" "258" ...
#  $ CO2             : chr  "Rating" "6" "4" "4" ...
#  $ Smog            : chr  "Rating" "3" "3" "3" ...
#  - attr(*, "spec")=List of 2
#   ..$ cols   :List of 221
#   .. ..$ Model           : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ Make            : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ Model_1         : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ Vehicle Class   : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ Engine Size     : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ Cylinders       : list()
#   .. .. ..- attr(*, "class")= chr  "collector_integer" "collector"
#   .. ..$ Transmission    : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ Fuel            : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ Fuel Consumption: list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X10             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X11             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X12             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ CO2 Emissions   : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ CO2             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ Smog            : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X16             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X17             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X18             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X19             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X20             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X21             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X22             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X23             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X24             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X25             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X26             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X27             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X28             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X29             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X30             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X31             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X32             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X33             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X34             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X35             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X36             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X37             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X38             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X39             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X40             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X41             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X42             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X43             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X44             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X45             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X46             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X47             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X48             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X49             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X50             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X51             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X52             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X53             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X54             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X55             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X56             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X57             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X58             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X59             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X60             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X61             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X62             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X63             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X64             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X65             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X66             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X67             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X68             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X69             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X70             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X71             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X72             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X73             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X74             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X75             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X76             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X77             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X78             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X79             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X80             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X81             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X82             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X83             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X84             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X85             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X86             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X87             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X88             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X89             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X90             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X91             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X92             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X93             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X94             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X95             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X96             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X97             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X98             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. ..$ X99             : list()
#   .. .. ..- attr(*, "class")= chr  "collector_character" "collector"
#   .. .. [list output truncated]
#   ..$ default: list()
#   .. ..- attr(*, "class")= chr  "collector_guess" "collector"
#   ..- attr(*, "class")= chr "col_spec"

# %% [markdown]
# ### Update the column names and remove the extra row
# This code looks the column names (which come from the first row of the file) and the first data row. Some columns have useful information spread over both rows, and some in only the first or second row.

# %%
names = colnames(data)
names
# Out:
#  [1] "Model"            "Make"             "Model_1"          "Vehicle Class"
#  [5] "Engine Size"      "Cylinders"        "Transmission"     "Fuel"
#  [9] "Fuel Consumption" "X10"              "X11"              "X12"
# [13] "CO2 Emissions"    "CO2"              "Smog"

# %%
# Update column names
clean_column_names <- function(data) {
    names = colnames(data)
    new_columns = rep("", length(names))

    for(i in 1:length(names)) {
        new_name = ""
        first_row_val = data[1, i]
        col = names[i]
        if (startsWith(col, "X")) {
            new_name = first_row_val
            }
        else if(is.na(first_row_val)) {
            new_name = col
            }
        else {
            new_name = str_c(col, first_row_val, sep=" ")
            }
        new_columns[i] = new_name
    }
    new_columns
}

new_columns <- clean_column_names(data)
new_columns
# Out:
# [[1]]
# [1] "Model Year"
#
# [[2]]
# [1] "Make"
#
# [[3]]
# [1] "Model_1"
#
# [[4]]
# [1] "Vehicle Class"
#
# [[5]]
# [1] "Engine Size (L)"
#
# [[6]]
# [1] "Cylinders"
#
# [[7]]
# [1] "Transmission"
#
# [[8]]
# [1] "Fuel Type"
#
# [[9]]
# [1] "Fuel Consumption City (L/100 km)"
#
# [[10]]
# [1] "Hwy (L/100 km)"
#
# [[11]]
# [1] "Comb (L/100 km)"
#
# [[12]]
# [1] "Comb (mpg)"
#
# [[13]]
# [1] "CO2 Emissions (g/km)"
#
# [[14]]
# [1] "CO2 Rating"
#
# [[15]]
# [1] "Smog Rating"

# %%
map_column <- function(original_name) {
    i <- which(original_name == names)
    return(new_columns[i])
}

map_column("X11")
# Out:
# [[1]]
# [1] "Comb (L/100 km)"

# %%
data <- data %>% rename_all(map_column)

# %% [markdown]
# ### Drop rows where anything is missing

# %%
data = drop_na(data)
data
# Out:
#      Model Year Make         Model_1                  Vehicle Class
# 1    2019       Acura        ILX                      Compact
# 2    2019       Acura        MDX SH-AWD               SUV: Small
# 3    2019       Acura        MDX SH-AWD A-SPEC        SUV: Small
# 4    2019       Acura        MDX Hybrid AWD           SUV: Small
# 5    2019       Acura        NSX                      Two-seater
# 6    2019       Acura        RDX AWD                  SUV: Small
# 7    2019       Acura        RDX AWD A-SPEC           SUV: Small
# 8    2019       Acura        RLX Hybrid               Mid-size
# 9    2019       Acura        TLX                      Compact
# 10   2019       Acura        TLX A-SPEC               Compact
# 11   2019       Acura        TLX SH-AWD               Compact
# 12   2019       Acura        TLX SH-AWD A-SPEC        Compact
# 13   2019       Alfa Romeo   4C Coupe                 Two-seater
# 14   2019       Alfa Romeo   4C Spider                Two-seater
# 15   2019       Alfa Romeo   Giulia                   Mid-size
# 16   2019       Alfa Romeo   Giulia AWD               Mid-size
# 17   2019       Alfa Romeo   Giulia Quadrifoglio      Mid-size
# 18   2019       Alfa Romeo   Stelvio                  SUV: Small
# 19   2019       Alfa Romeo   Stelvio AWD              SUV: Small
# 20   2019       Alfa Romeo   Stelvio AWD Quadrifoglio SUV: Small
# 21   2019       Aston Martin DB11 V8                  Minicompact
# 22   2019       Aston Martin DB11 AMR                 Minicompact
# 23   2019       Aston Martin DBS Superleggera         Minicompact
# 24   2019       Aston Martin Rapide AMR               Subcompact
# 25   2019       Aston Martin Vanquish Zagato          Minicompact
# 26   2019       Aston Martin Vantage V8               Two-seater
# 27   2019       Audi         A3                       Subcompact
# 28   2019       Audi         A3 quattro               Subcompact
# 29   2019       Audi         A3 Cabriolet quattro     Subcompact
# 30   2019       Audi         A4                       Compact
# ...  ...        ...          ...                      ...
# 993  2019       Volkswagen   Golf GTI                 Compact
# 994  2019       Volkswagen   Golf R                   Compact
# 995  2019       Volkswagen   Golf R                   Compact
# 996  2019       Volkswagen   Golf Alltrack            Station wagon: Small
# 997  2019       Volkswagen   Golf Alltrack            Station wagon: Small
# 998  2019       Volkswagen   Golf SportWagen          Station wagon: Small
# 999  2019       Volkswagen   Golf SportWagen          Station wagon: Small
# 1000 2019       Volkswagen   Golf SportWagen 4MOTION  Station wagon: Small
# 1001 2019       Volkswagen   Golf SportWagen 4MOTION  Station wagon: Small
# 1002 2019       Volkswagen   Jetta                    Compact
# 1003 2019       Volkswagen   Jetta                    Compact
# 1004 2019       Volkswagen   Jetta GLI                Compact
# 1005 2019       Volkswagen   Jetta GLI                Compact
# 1006 2019       Volkswagen   Passat                   Mid-size
# 1007 2019       Volkswagen   Tiguan                   SUV: Small
# 1008 2019       Volkswagen   Tiguan 4MOTION           SUV: Small
# 1009 2019       Volvo        S60 T5                   Compact
# 1010 2019       Volvo        S60 T6 AWD               Compact
# 1011 2019       Volvo        S90 T5 AWD               Mid-size
# 1012 2019       Volvo        S90 T6 AWD               Mid-size
# 1013 2019       Volvo        V60 T5                   Station wagon: Small
# 1014 2019       Volvo        V60 T6 AWD               Station wagon: Small
# 1015 2019       Volvo        V60 CC T5 AWD            Station wagon: Small
# 1016 2019       Volvo        V90 T6 AWD               Station wagon: Mid-size
# 1017 2019       Volvo        V90 CC T6 AWD            Station wagon: Mid-size
# 1018 2019       Volvo        XC40 T5 AWD              SUV: Small
# 1019 2019       Volvo        XC60 T5 AWD              SUV: Small
# 1020 2019       Volvo        XC60 T6 AWD              SUV: Small
# 1021 2019       Volvo        XC90 T5 AWD              SUV: Standard
# 1022 2019       Volvo        XC90 T6 AWD              SUV: Standard
#      Engine Size (L) Cylinders Transmission Fuel Type
# 1    2.4              4        AM8          Z
# 2    3.5              6        AS9          Z
# 3    3.5              6        AS9          Z
# 4    3.0              6        AM7          Z
# 5    3.5              6        AM9          Z
# 6    2.0              4        AS10         Z
# 7    2.0              4        AS10         Z
# 8    3.5              6        AM7          Z
# 9    2.4              4        AM8          Z
# 10   2.4              4        AM8          Z
# 11   3.5              6        AS9          Z
# 12   3.5              6        AS9          Z
# 13   1.8              4        AM6          Z
# 14   1.8              4        AM6          Z
# 15   2.0              4        A8           Z
# 16   2.0              4        A8           Z
# 17   2.9              6        A8           Z
# 18   2.0              4        A8           Z
# 19   2.0              4        A8           Z
# 20   2.9              6        A8           Z
# 21   4.0              8        A8           Z
# 22   5.2             12        A8           Z
# 23   5.2             12        A8           Z
# 24   6.0             12        A8           Z
# 25   6.0             12        A8           Z
# 26   4.0              8        A8           Z
# 27   2.0              4        AM7          X
# 28   2.0              4        AM7          X
# 29   2.0              4        AM7          X
# 30   2.0              4        AM7          Z
# ...  ...             ...       ...          ...
# 993  2.0             4         M6           X
# 994  2.0             4         AM7          Z
# 995  2.0             4         M6           Z
# 996  1.8             4         AM6          X
# 997  1.8             4         M6           X
# 998  1.4             4         AS8          X
# 999  1.4             4         M6           X
# 1000 1.8             4         AM6          X
# 1001 1.8             4         M6           X
# 1002 1.4             4         AM8          X
# 1003 1.4             4         M6           X
# 1004 2.0             4         AM7          X
# 1005 2.0             4         M6           X
# 1006 2.0             4         AS6          X
# 1007 2.0             4         AS8          X
# 1008 2.0             4         AS8          X
# 1009 2.0             4         AS8          Z
# 1010 2.0             4         AS8          Z
# 1011 2.0             4         AS8          Z
# 1012 2.0             4         AS8          Z
# 1013 2.0             4         AS8          Z
# 1014 2.0             4         AS8          Z
# 1015 2.0             4         AS8          Z
# 1016 2.0             4         AS8          Z
# 1017 2.0             4         AS8          Z
# 1018 2.0             4         AS8          Z
# 1019 2.0             4         AS8          Z
# 1020 2.0             4         AS8          Z
# 1021 2.0             4         AS8          Z
# 1022 2.0             4         AS8          Z
#      Fuel Consumption City (L/100 km) Hwy (L/100 km) Comb (L/100 km) Comb (mpg)
# 1    9.9                              7.0            8.6             33
# 2    12.2                             9.0            10.8            26
# 3    12.2                             9.5            11.0            26
# 4    9.1                              9.0            9.0             31
# 5    11.1                             10.8           11.0            26
# 6    11.0                             8.6            9.9             29
# 7    11.3                             9.1            10.3            27
# 8    8.4                              8.2            8.4             34
# 9    10.0                             7.1            8.7             32
# 10   10.2                             7.4            8.9             32
# 11   11.4                             7.7            9.8             29
# 12   12.0                             8.2            10.3            27
# 13   9.7                              6.9            8.4             34
# 14   9.7                              6.9            8.4             34
# 15   10.0                             7.2            8.7             32
# 16   10.5                             7.7            9.2             31
# 17   13.8                             9.6            11.9            24
# 18   10.3                             8.1            9.3             30
# 19   10.8                             8.3            9.6             29
# 20   14.1                             10.4           12.4            23
# 21   13.0                             9.8            11.5            25
# 22   15.5                             10.6           13.3            21
# 23   16.4                             10.7           13.8            20
# 24   16.7                             10.9           14.1            20
# 25   17.5                             11.4           14.7            19
# 26   12.7                             9.4            11.2            25
# 27   9.1                              6.8            8.1             35
# 28   10.9                             7.9            9.6             29
# 29   10.7                             7.9            9.5             30
# 30   8.6                              6.9            7.8             36
# ...  ...                              ...            ...             ...
# 993  9.8                              7.3            8.7             32
# 994  10.2                             7.9            9.2             31
# 995  11.4                             8.2            9.9             29
# 996  10.7                             8.0            9.4             30
# 997  11.1                             7.8            9.6             29
# 998  8.6                              6.5            7.6             37
# 999  8.2                              6.3            7.4             38
# 1000 10.8                             8.1            9.6             29
# 1001 10.8                             7.6            9.3             30
# 1002 7.8                              5.9            7.0             40
# 1003 7.9                              5.9            7.0             40
# 1004 9.3                              7.2            8.4             34
# 1005 9.6                              7.3            8.5             33
# 1006 9.3                              6.5            8.1             35
# 1007 10.7                             8.0            9.5             30
# 1008 11.1                             8.1            9.8             29
# 1009 9.9                              6.6            8.4             34
# 1010 11.1                             7.3            9.4             30
# 1011 10.6                             7.4            9.2             31
# 1012 11.1                             7.3            9.4             30
# 1013 9.9                              6.6            8.4             34
# 1014 11.1                             7.3            9.4             30
# 1015 10.8                             7.6            9.3             30
# 1016 11.1                             7.3            9.4             30
# 1017 11.6                             8.1            10.0            28
# 1018 10.3                             7.5            9.0             31
# 1019 11.3                             8.5            10.0            28
# 1020 11.8                             8.6            10.4            27
# 1021 11.3                             8.5            10.0            28
# 1022 12.1                             8.9            10.7            26
#      CO2 Emissions (g/km) CO2 Rating Smog Rating
# 1    199                  6          3
# 2    252                  4          3
# 3    258                  4          3
# 4    210                  5          3
# 5    261                  4          3
# 6    232                  5          6
# 7    242                  5          6
# 8    196                  6          7
# 9    205                  6          3
# 10   209                  5          3
# 11   228                  5          3
# 12   240                  5          3
# 13   197                  6          1
# 14   197                  6          1
# 15   205                  6          3
# 16   217                  5          3
# 17   280                  4          3
# 18   218                  5          3
# 19   226                  5          3
# 20   292                  3          3
# 21   271                  4          3
# 22   312                  3          3
# 23   324                  3          3
# 24   332                  3          3
# 25   346                  2          3
# 26   264                  4          3
# 27   188                  6          7
# 28   225                  5          7
# 29   221                  5          7
# 30   182                  7          5
# ...  ...                  ...        ...
# 993  203                  6          7
# 994  213                  5          3
# 995  232                  5          3
# 996  220                  5          7
# 997  225                  5          7
# 998  178                  7          7
# 999  172                  7          7
# 1000 224                  5          7
# 1001 218                  5          7
# 1002 163                  8          7
# 1003 163                  8          7
# 1004 196                  6          7
# 1005 200                  6          7
# 1006 188                  6          7
# 1007 221                  5          7
# 1008 228                  5          7
# 1009 197                  6          5
# 1010 218                  5          7
# 1011 215                  5          5
# 1012 219                  5          7
# 1013 197                  6          5
# 1014 219                  5          7
# 1015 218                  5          5
# 1016 219                  5          7
# 1017 233                  5          7
# 1018 211                  5          5
# 1019 233                  5          5
# 1020 242                  5          7
# 1021 233                  5          5
# 1022 250                  4          7

# %%
summary(data)
# Out:
#   Model Year            Make             Model_1          Vehicle Class
#  Length:1022        Length:1022        Length:1022        Length:1022
#  Class :character   Class :character   Class :character   Class :character
#  Mode  :character   Mode  :character   Mode  :character   Mode  :character
#
#
#
#  Engine Size (L)      Cylinders      Transmission        Fuel Type
#  Length:1022        Min.   : 3.000   Length:1022        Length:1022
#  Class :character   1st Qu.: 4.000   Class :character   Class :character
#  Mode  :character   Median : 6.000   Mode  :character   Mode  :character
#                     Mean   : 5.588
#                     3rd Qu.: 6.000
#                     Max.   :16.000
#  Fuel Consumption City (L/100 km) Hwy (L/100 km)     Comb (L/100 km)
#  Length:1022                      Length:1022        Length:1022
#  Class :character                 Class :character   Class :character
#  Mode  :character                 Mode  :character   Mode  :character
#
#
#
#   Comb (mpg)        CO2 Emissions (g/km)  CO2 Rating        Smog Rating
#  Length:1022        Length:1022          Length:1022        Length:1022
#  Class :character   Class :character     Class :character   Class :character
#  Mode  :character   Mode  :character     Mode  :character   Mode  :character

# %% [markdown]
# There are other columns that look numeric, why aren't they here?

# %% [markdown]
# Many columns got imported as 'character', meaning they are interptreted as text. Most of this is because of that 2 row header.

# %% [markdown]
# ### Convert to numeric:
# This converts the listed columns to numeric values.

# %%
numeric_cols = c("Model Year", "Engine Size (L)", "Fuel Consumption City (L/100 km)", "Hwy (L/100 km)", "Comb (L/100 km)", "Comb (mpg)", "CO2 Emissions (g/km)", "CO2 Rating", "Smog Rating")
str(data %>% mutate_at(numeric_cols,as.numeric))
# Out:
# Classes 'tbl_df', 'tbl' and 'data.frame':	1022 obs. of  15 variables:
#  $ Model Year                      : num  2019 2019 2019 2019 2019 ...
#  $ Make                            : chr  "Acura" "Acura" "Acura" "Acura" ...
#  $ Model_1                         : chr  "ILX" "MDX SH-AWD" "MDX SH-AWD A-SPEC" "MDX Hybrid AWD" ...
#  $ Vehicle Class                   : chr  "Compact" "SUV: Small" "SUV: Small" "SUV: Small" ...
#  $ Engine Size (L)                 : num  2.4 3.5 3.5 3 3.5 2 2 3.5 2.4 2.4 ...
#  $ Cylinders                       : int  4 6 6 6 6 4 4 6 4 4 ...
#  $ Transmission                    : chr  "AM8" "AS9" "AS9" "AM7" ...
#  $ Fuel Type                       : chr  "Z" "Z" "Z" "Z" ...
#  $ Fuel Consumption City (L/100 km): num  9.9 12.2 12.2 9.1 11.1 11 11.3 8.4 10 10.2 ...
#  $ Hwy (L/100 km)                  : num  7 9 9.5 9 10.8 8.6 9.1 8.2 7.1 7.4 ...
#  $ Comb (L/100 km)                 : num  8.6 10.8 11 9 11 9.9 10.3 8.4 8.7 8.9 ...
#  $ Comb (mpg)                      : num  33 26 26 31 26 29 27 34 32 32 ...
#  $ CO2 Emissions (g/km)            : num  199 252 258 210 261 232 242 196 205 209 ...
#  $ CO2 Rating                      : num  6 4 4 5 4 5 5 6 6 5 ...
#  $ Smog Rating                     : num  3 3 3 3 3 6 6 7 3 3 ...

# %% [markdown]
# ## Putting it all together to look at more years

# %%
a = c("a", "b")
b = c("b", "c")
intersect(a, b)
# Out:
# [1] "b"

# %%
clean = function(df) {
    df <- df %>% select_if(function(x) any(!is.na(x))) %>% drop_na
    names = colnames(df)
    new_names = c('Year', 'Make', 'Model', 'Class', 'Engine Size',
        'Cylinders', 'Transmission', 'Fuel Type',
        'Fuel Consumption City', 'Fuel Consumption Hwy', 'Fuel Consumption Comb',
        'Comb (mpg)', 'CO2 Emissions', 'CO2 Rating', 'Smog Rating')
    map_names <- function(original_name) {
        i <- which(original_name == names)
        return(new_names[i])
    }
   

    df <- df %>% rename_all(map_names)  
                           
    columns_to_convert = c("Year", "Engine Size", "Fuel Consumption City",'Fuel Consumption Hwy', 'Fuel Consumption Comb', "Comb (mpg)", "CO2 Emissions", "CO2 Rating", "Smog Rating")
    numeric_cols <- intersect(columns_to_convert, colnames(df)) # The columns from numeric_cols that exist in this dataset
    df <- df %>% mutate_at(numeric_cols,as.numeric)
    df 
}

clean(read_csv("downloads/MY2019 Fuel Consumption Ratings.csv"))
# Out:
# Warning message:
# "Missing column names filled in: 'X10' [10], 'X11' [11], 'X12' [12], 'X16' [16], 'X17' [17], 'X18' [18], 'X19' [19], 'X20' [20], 'X21' [21], 'X22' [22], 'X23' [23], 'X24' [24], 'X25' [25], 'X26' [26], 'X27' [27], 'X28' [28], 'X29' [29], 'X30' [30], 'X31' [31], 'X32' [32], 'X33' [33], 'X34' [34], 'X35' [35], 'X36' [36], 'X37' [37], 'X38' [38], 'X39' [39], 'X40' [40], 'X41' [41], 'X42' [42], 'X43' [43], 'X44' [44], 'X45' [45], 'X46' [46], 'X47' [47], 'X48' [48], 'X49' [49], 'X50' [50], 'X51' [51], 'X52' [52], 'X53' [53], 'X54' [54], 'X55' [55], 'X56' [56], 'X57' [57], 'X58' [58], 'X59' [59], 'X60' [60], 'X61' [61], 'X62' [62], 'X63' [63], 'X64' [64], 'X65' [65], 'X66' [66], 'X67' [67], 'X68' [68], 'X69' [69], 'X70' [70], 'X71' [71], 'X72' [72], 'X73' [73], 'X74' [74], 'X75' [75], 'X76' [76], 'X77' [77], 'X78' [78], 'X79' [79], 'X80' [80], 'X81' [81], 'X82' [82], 'X83' [83], 'X84' [84], 'X85' [85], 'X86' [86], 'X87' [87], 'X88' [88], 'X89' [89], 'X90' [90], 'X91' [91], 'X92' [92], 'X93' [93], 'X94' [94], 'X95' [95], 'X96' [96], 'X97' [97], 'X98' [98], 'X99' [99], 'X100' [100], 'X101' [101], 'X102' [102], 'X103' [103], 'X104' [104], 'X105' [105], 'X106' [106], 'X107' [107], 'X108' [108], 'X109' [109], 'X110' [110], 'X111' [111], 'X112' [112], 'X113' [113], 'X114' [114], 'X115' [115], 'X116' [116], 'X117' [117], 'X118' [118], 'X119' [119], 'X120' [120], 'X121' [121], 'X122' [122], 'X123' [123], 'X124' [124], 'X125' [125], 'X126' [126], 'X127' [127], 'X128' [128], 'X129' [129], 'X130' [130], 'X131' [131], 'X132' [132], 'X133' [133], 'X134' [134], 'X135' [135], 'X136' [136], 'X137' [137], 'X138' [138], 'X139' [139], 'X140' [140], 'X141' [141], 'X142' [142], 'X143' [143], 'X144' [144], 'X145' [145], 'X146' [146], 'X147' [147], 'X148' [148], 'X149' [149], 'X150' [150], 'X151' [151], 'X152' [152], 'X153' [153], 'X154' [154], 'X155' [155], 'X156' [156], 'X157' [157], 'X158' [158], 'X159' [159], 'X160' [160], 'X161' [161], 'X162' [162], 'X163' [163], 'X164' [164], 'X165' [165], 'X166' [166], 'X167' [167], 'X168' [168], 'X169' [169], 'X170' [170], 'X171' [171], 'X172' [172], 'X173' [173], 'X174' [174], 'X175' [175], 'X176' [176], 'X177' [177], 'X178' [178], 'X179' [179], 'X180' [180], 'X181' [181], 'X182' [182], 'X183' [183], 'X184' [184], 'X185' [185], 'X186' [186], 'X187' [187], 'X188' [188], 'X189' [189], 'X190' [190], 'X191' [191], 'X192' [192], 'X193' [193], 'X194' [194], 'X195' [195], 'X196' [196], 'X197' [197], 'X198' [198], 'X199' [199], 'X200' [200], 'X201' [201], 'X202' [202], 'X203' [203], 'X204' [204], 'X205' [205], 'X206' [206], 'X207' [207], 'X208' [208], 'X209' [209], 'X210' [210], 'X211' [211], 'X212' [212], 'X213' [213], 'X214' [214], 'X215' [215], 'X216' [216], 'X217' [217], 'X218' [218], 'X219' [219], 'X220' [220], 'X221' [221]"Warning message:
# "Duplicated column names deduplicated: 'Model' => 'Model_1' [3]"Parsed with column specification:
# cols(
#   .default = col_character(),
#   Cylinders = col_integer()
# )
# See spec(...) for full column specifications.
#      Year Make         Model                    Class
# 1    2019 Acura        ILX                      Compact
# 2    2019 Acura        MDX SH-AWD               SUV: Small
# 3    2019 Acura        MDX SH-AWD A-SPEC        SUV: Small
# 4    2019 Acura        MDX Hybrid AWD           SUV: Small
# 5    2019 Acura        NSX                      Two-seater
# 6    2019 Acura        RDX AWD                  SUV: Small
# 7    2019 Acura        RDX AWD A-SPEC           SUV: Small
# 8    2019 Acura        RLX Hybrid               Mid-size
# 9    2019 Acura        TLX                      Compact
# 10   2019 Acura        TLX A-SPEC               Compact
# 11   2019 Acura        TLX SH-AWD               Compact
# 12   2019 Acura        TLX SH-AWD A-SPEC        Compact
# 13   2019 Alfa Romeo   4C Coupe                 Two-seater
# 14   2019 Alfa Romeo   4C Spider                Two-seater
# 15   2019 Alfa Romeo   Giulia                   Mid-size
# 16   2019 Alfa Romeo   Giulia AWD               Mid-size
# 17   2019 Alfa Romeo   Giulia Quadrifoglio      Mid-size
# 18   2019 Alfa Romeo   Stelvio                  SUV: Small
# 19   2019 Alfa Romeo   Stelvio AWD              SUV: Small
# 20   2019 Alfa Romeo   Stelvio AWD Quadrifoglio SUV: Small
# 21   2019 Aston Martin DB11 V8                  Minicompact
# 22   2019 Aston Martin DB11 AMR                 Minicompact
# 23   2019 Aston Martin DBS Superleggera         Minicompact
# 24   2019 Aston Martin Rapide AMR               Subcompact
# 25   2019 Aston Martin Vanquish Zagato          Minicompact
# 26   2019 Aston Martin Vantage V8               Two-seater
# 27   2019 Audi         A3                       Subcompact
# 28   2019 Audi         A3 quattro               Subcompact
# 29   2019 Audi         A3 Cabriolet quattro     Subcompact
# 30   2019 Audi         A4                       Compact
# ...  ...  ...          ...                      ...
# 993  2019 Volkswagen   Golf GTI                 Compact
# 994  2019 Volkswagen   Golf R                   Compact
# 995  2019 Volkswagen   Golf R                   Compact
# 996  2019 Volkswagen   Golf Alltrack            Station wagon: Small
# 997  2019 Volkswagen   Golf Alltrack            Station wagon: Small
# 998  2019 Volkswagen   Golf SportWagen          Station wagon: Small
# 999  2019 Volkswagen   Golf SportWagen          Station wagon: Small
# 1000 2019 Volkswagen   Golf SportWagen 4MOTION  Station wagon: Small
# 1001 2019 Volkswagen   Golf SportWagen 4MOTION  Station wagon: Small
# 1002 2019 Volkswagen   Jetta                    Compact
# 1003 2019 Volkswagen   Jetta                    Compact
# 1004 2019 Volkswagen   Jetta GLI                Compact
# 1005 2019 Volkswagen   Jetta GLI                Compact
# 1006 2019 Volkswagen   Passat                   Mid-size
# 1007 2019 Volkswagen   Tiguan                   SUV: Small
# 1008 2019 Volkswagen   Tiguan 4MOTION           SUV: Small
# 1009 2019 Volvo        S60 T5                   Compact
# 1010 2019 Volvo        S60 T6 AWD               Compact
# 1011 2019 Volvo        S90 T5 AWD               Mid-size
# 1012 2019 Volvo        S90 T6 AWD               Mid-size
# 1013 2019 Volvo        V60 T5                   Station wagon: Small
# 1014 2019 Volvo        V60 T6 AWD               Station wagon: Small
# 1015 2019 Volvo        V60 CC T5 AWD            Station wagon: Small
# 1016 2019 Volvo        V90 T6 AWD               Station wagon: Mid-size
# 1017 2019 Volvo        V90 CC T6 AWD            Station wagon: Mid-size
# 1018 2019 Volvo        XC40 T5 AWD              SUV: Small
# 1019 2019 Volvo        XC60 T5 AWD              SUV: Small
# 1020 2019 Volvo        XC60 T6 AWD              SUV: Small
# 1021 2019 Volvo        XC90 T5 AWD              SUV: Standard
# 1022 2019 Volvo        XC90 T6 AWD              SUV: Standard
#      Engine Size Cylinders Transmission Fuel Type Fuel Consumption City
# 1    2.4          4        AM8          Z          9.9
# 2    3.5          6        AS9          Z         12.2
# 3    3.5          6        AS9          Z         12.2
# 4    3.0          6        AM7          Z          9.1
# 5    3.5          6        AM9          Z         11.1
# 6    2.0          4        AS10         Z         11.0
# 7    2.0          4        AS10         Z         11.3
# 8    3.5          6        AM7          Z          8.4
# 9    2.4          4        AM8          Z         10.0
# 10   2.4          4        AM8          Z         10.2
# 11   3.5          6        AS9          Z         11.4
# 12   3.5          6        AS9          Z         12.0
# 13   1.8          4        AM6          Z          9.7
# 14   1.8          4        AM6          Z          9.7
# 15   2.0          4        A8           Z         10.0
# 16   2.0          4        A8           Z         10.5
# 17   2.9          6        A8           Z         13.8
# 18   2.0          4        A8           Z         10.3
# 19   2.0          4        A8           Z         10.8
# 20   2.9          6        A8           Z         14.1
# 21   4.0          8        A8           Z         13.0
# 22   5.2         12        A8           Z         15.5
# 23   5.2         12        A8           Z         16.4
# 24   6.0         12        A8           Z         16.7
# 25   6.0         12        A8           Z         17.5
# 26   4.0          8        A8           Z         12.7
# 27   2.0          4        AM7          X          9.1
# 28   2.0          4        AM7          X         10.9
# 29   2.0          4        AM7          X         10.7
# 30   2.0          4        AM7          Z          8.6
# ...  ...         ...       ...          ...       ...
# 993  2.0         4         M6           X          9.8
# 994  2.0         4         AM7          Z         10.2
# 995  2.0         4         M6           Z         11.4
# 996  1.8         4         AM6          X         10.7
# 997  1.8         4         M6           X         11.1
# 998  1.4         4         AS8          X          8.6
# 999  1.4         4         M6           X          8.2
# 1000 1.8         4         AM6          X         10.8
# 1001 1.8         4         M6           X         10.8
# 1002 1.4         4         AM8          X          7.8
# 1003 1.4         4         M6           X          7.9
# 1004 2.0         4         AM7          X          9.3
# 1005 2.0         4         M6           X          9.6
# 1006 2.0         4         AS6          X          9.3
# 1007 2.0         4         AS8          X         10.7
# 1008 2.0         4         AS8          X         11.1
# 1009 2.0         4         AS8          Z          9.9
# 1010 2.0         4         AS8          Z         11.1
# 1011 2.0         4         AS8          Z         10.6
# 1012 2.0         4         AS8          Z         11.1
# 1013 2.0         4         AS8          Z          9.9
# 1014 2.0         4         AS8          Z         11.1
# 1015 2.0         4         AS8          Z         10.8
# 1016 2.0         4         AS8          Z         11.1
# 1017 2.0         4         AS8          Z         11.6
# 1018 2.0         4         AS8          Z         10.3
# 1019 2.0         4         AS8          Z         11.3
# 1020 2.0         4         AS8          Z         11.8
# 1021 2.0         4         AS8          Z         11.3
# 1022 2.0         4         AS8          Z         12.1
#      Fuel Consumption Hwy Fuel Consumption Comb Comb (mpg) CO2 Emissions
# 1     7.0                  8.6                  33         199
# 2     9.0                 10.8                  26         252
# 3     9.5                 11.0                  26         258
# 4     9.0                  9.0                  31         210
# 5    10.8                 11.0                  26         261
# 6     8.6                  9.9                  29         232
# 7     9.1                 10.3                  27         242
# 8     8.2                  8.4                  34         196
# 9     7.1                  8.7                  32         205
# 10    7.4                  8.9                  32         209
# 11    7.7                  9.8                  29         228
# 12    8.2                 10.3                  27         240
# 13    6.9                  8.4                  34         197
# 14    6.9                  8.4                  34         197
# 15    7.2                  8.7                  32         205
# 16    7.7                  9.2                  31         217
# 17    9.6                 11.9                  24         280
# 18    8.1                  9.3                  30         218
# 19    8.3                  9.6                  29         226
# 20   10.4                 12.4                  23         292
# 21    9.8                 11.5                  25         271
# 22   10.6                 13.3                  21         312
# 23   10.7                 13.8                  20         324
# 24   10.9                 14.1                  20         332
# 25   11.4                 14.7                  19         346
# 26    9.4                 11.2                  25         264
# 27    6.8                  8.1                  35         188
# 28    7.9                  9.6                  29         225
# 29    7.9                  9.5                  30         221
# 30    6.9                  7.8                  36         182
# ...  ...                  ...                   ...        ...
# 993  7.3                   8.7                  32         203
# 994  7.9                   9.2                  31         213
# 995  8.2                   9.9                  29         232
# 996  8.0                   9.4                  30         220
# 997  7.8                   9.6                  29         225
# 998  6.5                   7.6                  37         178
# 999  6.3                   7.4                  38         172
# 1000 8.1                   9.6                  29         224
# 1001 7.6                   9.3                  30         218
# 1002 5.9                   7.0                  40         163
# 1003 5.9                   7.0                  40         163
# 1004 7.2                   8.4                  34         196
# 1005 7.3                   8.5                  33         200
# 1006 6.5                   8.1                  35         188
# 1007 8.0                   9.5                  30         221
# 1008 8.1                   9.8                  29         228
# 1009 6.6                   8.4                  34         197
# 1010 7.3                   9.4                  30         218
# 1011 7.4                   9.2                  31         215
# 1012 7.3                   9.4                  30         219
# 1013 6.6                   8.4                  34         197
# 1014 7.3                   9.4                  30         219
# 1015 7.6                   9.3                  30         218
# 1016 7.3                   9.4                  30         219
# 1017 8.1                  10.0                  28         233
# 1018 7.5                   9.0                  31         211
# 1019 8.5                  10.0                  28         233
# 1020 8.6                  10.4                  27         242
# 1021 8.5                  10.0                  28         233
# 1022 8.9                  10.7                  26         250
#      CO2 Rating Smog Rating
# 1    6          3
# 2    4          3
# 3    4          3
# 4    5          3
# 5    4          3
# 6    5          6
# 7    5          6
# 8    6          7
# 9    6          3
# 10   5          3
# 11   5          3
# 12   5          3
# 13   6          1
# 14   6          1
# 15   6          3
# 16   5          3
# 17   4          3
# 18   5          3
# 19   5          3
# 20   3          3
# 21   4          3
# 22   3          3
# 23   3          3
# 24   3          3
# 25   2          3
# 26   4          3
# 27   6          7
# 28   5          7
# 29   5          7
# 30   7          5
# ...  ...        ...
# 993  6          7
# 994  5          3
# 995  5          3
# 996  5          7
# 997  5          7
# 998  7          7
# 999  7          7
# 1000 5          7
# 1001 5          7
# 1002 8          7
# 1003 8          7
# 1004 6          7
# 1005 6          7
# 1006 6          7
# 1007 5          7
# 1008 5          7
# 1009 6          5
# 1010 5          7
# 1011 5          5
# 1012 5          7
# 1013 6          5
# 1014 5          7
# 1015 5          5
# 1016 5          7
# 1017 5          7
# 1018 5          5
# 1019 5          5
# 1020 5          7
# 1021 5          5
# 1022 4          7

# %%
my2000 = read_csv("downloads/MY2000 Fuel Consumption Ratings 5-cycle.csv")
# Out:
# Warning message:
# "Missing column names filled in: 'X10' [10], 'X11' [11], 'X12' [12]"Warning message:
# "Duplicated column names deduplicated: 'MODEL' => 'MODEL_1' [3]"Parsed with column specification:
# cols(
#   MODEL = col_character(),
#   MAKE = col_character(),
#   MODEL_1 = col_character(),
#   `VEHICLE CLASS` = col_character(),
#   `ENGINE SIZE` = col_character(),
#   CYLINDERS = col_integer(),
#   TRANSMISSION = col_character(),
#   FUEL = col_character(),
#   `FUEL CONSUMPTION*` = col_character(),
#   X10 = col_character(),
#   X11 = col_character(),
#   X12 = col_character(),
#   `CO2 EMISSIONS` = col_character()
# )

# %%
head(my2000)
# Out:
#   MODEL MAKE  MODEL_1                VEHICLE CLASS ENGINE SIZE CYLINDERS
# 1 YEAR  NA    # = high output engine NA            (L)         NA
# 2 2000  ACURA 1.6EL                  COMPACT       1.6          4
# 3 2000  ACURA 1.6EL                  COMPACT       1.6          4
# 4 2000  ACURA 3.2TL                  MID-SIZE      3.2          6
# 5 2000  ACURA 3.5RL                  MID-SIZE      3.5          6
# 6 2000  ACURA INTEGRA                SUBCOMPACT    1.8          4
#   TRANSMISSION FUEL FUEL CONSUMPTION* X10            X11             X12
# 1 NA           TYPE CITY (L/100 km)   HWY (L/100 km) COMB (L/100 km) COMB (mpg)
# 2 A4           X    10.5              8              9.4             30
# 3 M5           X    9.8               7.8            8.9             32
# 4 AS5          Z    13.7              8.8            11.5            25
# 5 A4           Z    15                10.9           13.1            22
# 6 A4           X    11.4              8.3            10              28
#   CO2 EMISSIONS
# 1 (g/km)
# 2 216
# 3 205
# 4 265
# 5 301
# 6 230

# %%
clean(my2000)
# Out:
#     Year Make       Model                           Class
# 1   2000 ACURA      1.6EL                           COMPACT
# 2   2000 ACURA      1.6EL                           COMPACT
# 3   2000 ACURA      3.2TL                           MID-SIZE
# 4   2000 ACURA      3.5RL                           MID-SIZE
# 5   2000 ACURA      INTEGRA                         SUBCOMPACT
# 6   2000 ACURA      INTEGRA                         SUBCOMPACT
# 7   2000 ACURA      INTEGRA GSR/TYPE R              SUBCOMPACT
# 8   2000 ACURA      NSX                             SUBCOMPACT
# 9   2000 ACURA      NSX                             SUBCOMPACT
# 10  2000 AUDI       A4                              COMPACT
# 11  2000 AUDI       A4                              COMPACT
# 12  2000 AUDI       A4                              COMPACT
# 13  2000 AUDI       A4                              COMPACT
# 14  2000 AUDI       A4 QUATTRO                      COMPACT
# 15  2000 AUDI       A4 QUATTRO                      COMPACT
# 16  2000 AUDI       A4 QUATTRO                      COMPACT
# 17  2000 AUDI       A4 QUATTRO                      COMPACT
# 18  2000 AUDI       A6                              MID-SIZE
# 19  2000 AUDI       A6 AVANT QUATTRO                STATION WAGON - MID-SIZE
# 20  2000 AUDI       A6 QUATTRO                      MID-SIZE
# 21  2000 AUDI       A6 QUATTRO                      MID-SIZE
# 22  2000 AUDI       A6 QUATTRO                      MID-SIZE
# 23  2000 AUDI       A6 QUATTRO                      MID-SIZE
# 24  2000 AUDI       A6 QUATTRO                      MID-SIZE
# 25  2000 AUDI       A8 QUATTRO                      MID-SIZE
# 26  2000 AUDI       S4 QUATTRO                      COMPACT
# 27  2000 AUDI       S4 QUATTRO                      COMPACT
# 28  2000 AUDI       TT COUPE QUATTRO                MINICOMPACT
# 29  2000 AUDI       TT COUPE QUATTRO (SUPERCHARGED) MINICOMPACT
# 30  2000 AUDI       TT ROADSTER                     TWO-SEATER
# ... ...  ...        ...                             ...
# 610 2000 VOLKSWAGEN NEW BEETLE TDI DIESEL           SUBCOMPACT
# 611 2000 VOLKSWAGEN PASSAT                          MID-SIZE
# 612 2000 VOLKSWAGEN PASSAT                          MID-SIZE
# 613 2000 VOLKSWAGEN PASSAT                          MID-SIZE
# 614 2000 VOLKSWAGEN PASSAT                          MID-SIZE
# 615 2000 VOLKSWAGEN PASSAT WAGON                    STATION WAGON - MID-SIZE
# 616 2000 VOLKSWAGEN PASSAT WAGON                    STATION WAGON - MID-SIZE
# 617 2000 VOLKSWAGEN PASSAT WAGON                    STATION WAGON - MID-SIZE
# 618 2000 VOLKSWAGEN PASSAT WAGON                    STATION WAGON - MID-SIZE
# 619 2000 VOLVO      C70 CONVERTIBLE TURBO           SUBCOMPACT
# 620 2000 VOLVO      C70 CONVERTIBLE TURBO           SUBCOMPACT
# 621 2000 VOLVO      C70 CONVERTIBLE TURBO           SUBCOMPACT
# 622 2000 VOLVO      C70 TURBO                       COMPACT
# 623 2000 VOLVO      C70 TURBO                       COMPACT
# 624 2000 VOLVO      C70 TURBO                       COMPACT
# 625 2000 VOLVO      S70                             MID-SIZE
# 626 2000 VOLVO      S70                             MID-SIZE
# 627 2000 VOLVO      S70 AWD TURBO                   MID-SIZE
# 628 2000 VOLVO      S70 GLT TURBO                   MID-SIZE
# 629 2000 VOLVO      S70 T5 TURBO                    MID-SIZE
# 630 2000 VOLVO      S70 T5 TURBO                    MID-SIZE
# 631 2000 VOLVO      S80 2.9                         MID-SIZE
# 632 2000 VOLVO      S80 T-6                         MID-SIZE
# 633 2000 VOLVO      V70                             STATION WAGON - MID-SIZE
# 634 2000 VOLVO      V70                             STATION WAGON - MID-SIZE
# 635 2000 VOLVO      V70 AWD TURBO                   STATION WAGON - MID-SIZE
# 636 2000 VOLVO      V70 GLT TURBO                   STATION WAGON - MID-SIZE
# 637 2000 VOLVO      V70 T5 TURBO                    STATION WAGON - MID-SIZE
# 638 2000 VOLVO      V70 T5 TURBO                    STATION WAGON - MID-SIZE
# 639 2000 VOLVO      V70R AWD TURBO                  STATION WAGON - MID-SIZE
#     Engine Size Cylinders Transmission Fuel Type Fuel Consumption City
# 1   1.6         4         A4           X         10.5
# 2   1.6         4         M5           X          9.8
# 3   3.2         6         AS5          Z         13.7
# 4   3.5         6         A4           Z         15.0
# 5   1.8         4         A4           X         11.4
# 6   1.8         4         M5           X         10.6
# 7   1.8         4         M5           Z         10.8
# 8   3.0         6         AS4          Z         15.2
# 9   3.2         6         M6           Z         15.4
# 10  1.8         4         A5           Z         12.9
# 11  1.8         4         M5           Z         11.1
# 12  2.8         6         A5           Z         14.6
# 13  2.8         6         M5           Z         13.2
# 14  1.8         4         A5           Z         13.6
# 15  1.8         4         M5           Z         12.1
# 16  2.8         6         A5           Z         14.9
# 17  2.8         6         M5           Z         14.3
# 18  2.8         6         A5           Z         15.0
# 19  2.8         6         A5           Z         15.4
# 20  2.7         6         A5           Z         15.2
# 21  2.7         6         M6           Z         15.2
# 22  2.8         6         A5           Z         15.4
# 23  2.8         6         M5           Z         14.6
# 24  4.2         8         A5           Z         15.5
# 25  4.2         8         A5           Z         15.5
# 26  2.7         6         A5           Z         15.2
# 27  2.7         6         M6           Z         15.2
# 28  1.8         4         M5           Z         13.1
# 29  1.8         4         M6           Z         13.1
# 30  1.8         4         M5           Z         12.3
# ... ...         ...       ...          ...       ...
# 610 1.9         4         M5           D          6.7
# 611 1.8         4         A5           Z         13.2
# 612 1.8         4         M5           Z         11.2
# 613 2.8         6         A5           Z         14.7
# 614 2.8         6         M5           Z         13.4
# 615 1.8         4         A5           Z         13.2
# 616 1.8         4         M5           Z         11.2
# 617 2.8         6         A5           Z         14.7
# 618 2.8         6         M5           Z         13.4
# 619 2.3         5         A4           Z         14.2
# 620 2.3         5         M5           Z         13.4
# 621 2.4         5         A4           Z         13.9
# 622 2.3         5         A4           Z         13.9
# 623 2.3         5         M5           Z         13.0
# 624 2.4         5         A4           Z         13.6
# 625 2.4         5         A5           Z         13.2
# 626 2.4         5         M5           Z         12.6
# 627 2.4         5         A4           Z         14.4
# 628 2.4         5         A4           Z         13.6
# 629 2.3         5         A4           Z         13.9
# 630 2.3         5         M5           Z         13.0
# 631 2.9         6         A4           Z         14.5
# 632 2.8         6         AS4          Z         15.1
# 633 2.4         5         A5           Z         13.2
# 634 2.4         5         M5           Z         12.6
# 635 2.4         5         A4           Z         14.4
# 636 2.4         5         A4           Z         13.6
# 637 2.3         5         A4           Z         13.9
# 638 2.3         5         M5           Z         13.0
# 639 2.4         5         A5           Z         14.7
#     Fuel Consumption Hwy Fuel Consumption Comb Comb (mpg) CO2 Emissions
# 1    8.0                  9.4                  30         216
# 2    7.8                  8.9                  32         205
# 3    8.8                 11.5                  25         265
# 4   10.9                 13.1                  22         301
# 5    8.3                 10.0                  28         230
# 6    8.1                  9.5                  30         219
# 7    8.3                  9.7                  29         223
# 8   10.9                 13.3                  21         306
# 9   10.7                 13.3                  21         306
# 10   8.6                 10.9                  26         251
# 11   8.1                  9.7                  29         223
# 12   9.7                 12.4                  23         285
# 13   8.9                 11.3                  25         260
# 14   9.1                 11.6                  24         267
# 15   8.9                 10.7                  26         246
# 16  10.1                 12.7                  22         292
# 17  10.3                 12.5                  23         288
# 18  10.2                 12.8                  22         294
# 19  10.7                 13.3                  21         306
# 20  10.6                 13.2                  21         304
# 21  10.7                 13.2                  21         304
# 22  10.7                 13.3                  21         306
# 23  10.9                 12.9                  22         297
# 24  10.7                 13.4                  21         308
# 25  10.7                 13.4                  21         308
# 26  10.6                 13.2                  21         304
# 27  10.7                 13.2                  21         304
# 28   9.0                 11.3                  25         260
# 29   9.1                 11.3                  25         260
# 30   8.7                 10.7                  26         246
# ... ...                  ...                   ...        ...
# 610  5.4                  6.1                  46         165
# 611  8.7                 11.2                  25         258
# 612  8.2                  9.8                  29         225
# 613  9.8                 12.5                  23         288
# 614  8.9                 11.4                  25         262
# 615  8.7                 11.2                  25         258
# 616  8.2                  9.8                  29         225
# 617  9.8                 12.5                  23         288
# 618  8.9                 11.4                  25         262
# 619 10.3                 12.4                  23         285
# 620  9.7                 11.7                  24         269
# 621  9.8                 12.1                  23         278
# 622  9.5                 11.9                  24         274
# 623  9.3                 11.3                  25         260
# 624  9.7                 11.9                  24         274
# 625  9.3                 11.4                  25         262
# 626  8.9                 10.9                  26         251
# 627 10.3                 12.5                  23         288
# 628  9.7                 11.9                  24         274
# 629  9.5                 11.9                  24         274
# 630  9.3                 11.3                  25         260
# 631  9.9                 12.4                  23         285
# 632 10.3                 12.9                  22         297
# 633  9.3                 11.4                  25         262
# 634  8.9                 10.9                  26         251
# 635 10.3                 12.5                  23         288
# 636  9.7                 11.9                  24         274
# 637  9.5                 11.9                  24         274
# 638  9.3                 11.3                  25         260
# 639 10.9                 13.0                  22         299

# %%
load_all_years <- function(files) {
    all_data_list <- lapply(files, function(f) { suppressWarnings(clean(read_csv(f)))})
    #all_data_list
    bind_rows(all_data_list)
}

# %%
combined <- load_all_years(en_consumption_files)

# %%
summary(combined)
# Out:
# < table of extent 0 x 0 >

# %% [markdown]
# And now I want to do all that again but using the French data files - maybe to compare that they're the same. Now that it's all set up, it's easy!

# %%
fr_consumption_files <- list.files(pattern="downloads/MY[0-9]{4} Fuel Consumption Ratings.*csv")
fr_combined <- load_all_years(fr_consumption_files)

# %%
summary(fr_combined)
# Out:
# < table of extent 0 x 0 >

# %% [markdown]
# ## There's often more than one way to do it
# Another way to deal with a two line header, or other scenarios where there is extra data at the start of a file, is to set the `col_names`, and `skip` options when reading in the file.

# %%
# It will deal with too many columns just fine
newer_colnames = c('Year', 'Make', 'Model', 'Class', 'Engine Size',
        'Cylinders', 'Transmission', 'Fuel Type',
        'Fuel Consumption City', 'Fuel Consumption Hwy', 'Fuel Consumption Comb',
        'Comb (mpg)', 'CO2 Emissions', 'CO2 Rating', 'Smog Rating')
read_csv("downloads/MY2019 Fuel Consumption Ratings.csv", col_names=newer_colnames, skip=3)
# Out:
# Parsed with column specification:
# cols(
#   Year = col_integer(),
#   Make = col_character(),
#   Model = col_character(),
#   Class = col_character(),
#   `Engine Size` = col_double(),
#   Cylinders = col_integer(),
#   Transmission = col_character(),
#   `Fuel Type` = col_character(),
#   `Fuel Consumption City` = col_double(),
#   `Fuel Consumption Hwy` = col_double(),
#   `Fuel Consumption Comb` = col_double(),
#   `Comb (mpg)` = col_integer(),
#   `CO2 Emissions` = col_integer(),
#   `CO2 Rating` = col_integer(),
#   `Smog Rating` = col_integer()
# )
# Warning message in rbind(names(probs), probs_f):
# "number of columns of result is not a multiple of vector length (arg 1)"Warning message:
# "1290 parsing failures.
# row # A tibble: 5 x 5 col     row col   expected   actual      file                                       expected   <int> <chr> <chr>      <chr>       <chr>                                      actual 1     1 <NA>  15 columns 221 columns 'downloads/MY2019 Fuel Consumption Rating~ file 2     2 <NA>  15 columns 221 columns 'downloads/MY2019 Fuel Consumption Rating~ row 3     3 <NA>  15 columns 221 columns 'downloads/MY2019 Fuel Consumption Rating~ col 4     4 <NA>  15 columns 221 columns 'downloads/MY2019 Fuel Consumption Rating~ expected 5     5 <NA>  15 columns 221 columns 'downloads/MY2019 Fuel Consumption Rating~
# ... ................. ... ............................................................................... ........ ............................................................................... ...... ............................................................................... .... ............................................................................... ... ............................................................................... ... ............................................................................... ........ ...............................................................................
# See problems(...) for more details.
# "
#      Year Make         Model                    Class       Engine Size
# 1    2019 Acura        ILX                      Compact     2.4
# 2    2019 Acura        MDX SH-AWD               SUV: Small  3.5
# 3    2019 Acura        MDX SH-AWD A-SPEC        SUV: Small  3.5
# 4    2019 Acura        MDX Hybrid AWD           SUV: Small  3.0
# 5    2019 Acura        NSX                      Two-seater  3.5
# 6    2019 Acura        RDX AWD                  SUV: Small  2.0
# 7    2019 Acura        RDX AWD A-SPEC           SUV: Small  2.0
# 8    2019 Acura        RLX Hybrid               Mid-size    3.5
# 9    2019 Acura        TLX                      Compact     2.4
# 10   2019 Acura        TLX A-SPEC               Compact     2.4
# 11   2019 Acura        TLX SH-AWD               Compact     3.5
# 12   2019 Acura        TLX SH-AWD A-SPEC        Compact     3.5
# 13   2019 Alfa Romeo   4C Coupe                 Two-seater  1.8
# 14   2019 Alfa Romeo   4C Spider                Two-seater  1.8
# 15   2019 Alfa Romeo   Giulia                   Mid-size    2.0
# 16   2019 Alfa Romeo   Giulia AWD               Mid-size    2.0
# 17   2019 Alfa Romeo   Giulia Quadrifoglio      Mid-size    2.9
# 18   2019 Alfa Romeo   Stelvio                  SUV: Small  2.0
# 19   2019 Alfa Romeo   Stelvio AWD              SUV: Small  2.0
# 20   2019 Alfa Romeo   Stelvio AWD Quadrifoglio SUV: Small  2.9
# 21   2019 Aston Martin DB11 V8                  Minicompact 4.0
# 22   2019 Aston Martin DB11 AMR                 Minicompact 5.2
# 23   2019 Aston Martin DBS Superleggera         Minicompact 5.2
# 24   2019 Aston Martin Rapide AMR               Subcompact  6.0
# 25   2019 Aston Martin Vanquish Zagato          Minicompact 6.0
# 26   2019 Aston Martin Vantage V8               Two-seater  4.0
# 27   2019 Audi         A3                       Subcompact  2.0
# 28   2019 Audi         A3 quattro               Subcompact  2.0
# 29   2019 Audi         A3 Cabriolet quattro     Subcompact  2.0
# 30   2019 Audi         A4                       Compact     2.0
# ...  ...  ...          ...                      ...         ...
# 1253 NA   NA           NA                       NA          NA
# 1254 NA   NA           NA                       NA          NA
# 1255 NA   NA           NA                       NA          NA
# 1256 NA   NA           NA                       NA          NA
# 1257 NA   NA           NA                       NA          NA
# 1258 NA   NA           NA                       NA          NA
# 1259 NA   NA           NA                       NA          NA
# 1260 NA   NA           NA                       NA          NA
# 1261 NA   NA           NA                       NA          NA
# 1262 NA   NA           NA                       NA          NA
# 1263 NA   NA           NA                       NA          NA
# 1264 NA   NA           NA                       NA          NA
# 1265 NA   NA           NA                       NA          NA
# 1266 NA   NA           NA                       NA          NA
# 1267 NA   NA           NA                       NA          NA
# 1268 NA   NA           NA                       NA          NA
# 1269 NA   NA           NA                       NA          NA
# 1270 NA   NA           NA                       NA          NA
# 1271 NA   NA           NA                       NA          NA
# 1272 NA   NA           NA                       NA          NA
# 1273 NA   NA           NA                       NA          NA
# 1274 NA   NA           NA                       NA          NA
# 1275 NA   NA           NA                       NA          NA
# 1276 NA   NA           NA                       NA          NA
# 1277 NA   NA           NA                       NA          NA
# 1278 NA   NA           NA                       NA          NA
# 1279 NA   NA           NA                       NA          NA
# 1280 NA   NA           NA                       NA          NA
# 1281 NA   NA           NA                       NA          NA
# 1282 NA   NA           NA                       NA          NA
#      Cylinders Transmission Fuel Type Fuel Consumption City
# 1     4        AM8          Z          9.9
# 2     6        AS9          Z         12.2
# 3     6        AS9          Z         12.2
# 4     6        AM7          Z          9.1
# 5     6        AM9          Z         11.1
# 6     4        AS10         Z         11.0
# 7     4        AS10         Z         11.3
# 8     6        AM7          Z          8.4
# 9     4        AM8          Z         10.0
# 10    4        AM8          Z         10.2
# 11    6        AS9          Z         11.4
# 12    6        AS9          Z         12.0
# 13    4        AM6          Z          9.7
# 14    4        AM6          Z          9.7
# 15    4        A8           Z         10.0
# 16    4        A8           Z         10.5
# 17    6        A8           Z         13.8
# 18    4        A8           Z         10.3
# 19    4        A8           Z         10.8
# 20    6        A8           Z         14.1
# 21    8        A8           Z         13.0
# 22   12        A8           Z         15.5
# 23   12        A8           Z         16.4
# 24   12        A8           Z         16.7
# 25   12        A8           Z         17.5
# 26    8        A8           Z         12.7
# 27    4        AM7          X          9.1
# 28    4        AM7          X         10.9
# 29    4        AM7          X         10.7
# 30    4        AM7          Z          8.6
# ...  ...       ...          ...       ...
# 1253 NA        NA           NA        NA
# 1254 NA        NA           NA        NA
# 1255 NA        NA           NA        NA
# 1256 NA        NA           NA        NA
# 1257 NA        NA           NA        NA
# 1258 NA        NA           NA        NA
# 1259 NA        NA           NA        NA
# 1260 NA        NA           NA        NA
# 1261 NA        NA           NA        NA
# 1262 NA        NA           NA        NA
# 1263 NA        NA           NA        NA
# 1264 NA        NA           NA        NA
# 1265 NA        NA           NA        NA
# 1266 NA        NA           NA        NA
# 1267 NA        NA           NA        NA
# 1268 NA        NA           NA        NA
# 1269 NA        NA           NA        NA
# 1270 NA        NA           NA        NA
# 1271 NA        NA           NA        NA
# 1272 NA        NA           NA        NA
# 1273 NA        NA           NA        NA
# 1274 NA        NA           NA        NA
# 1275 NA        NA           NA        NA
# 1276 NA        NA           NA        NA
# 1277 NA        NA           NA        NA
# 1278 NA        NA           NA        NA
# 1279 NA        NA           NA        NA
# 1280 NA        NA           NA        NA
# 1281 NA        NA           NA        NA
# 1282 NA        NA           NA        NA
#      Fuel Consumption Hwy Fuel Consumption Comb Comb (mpg) CO2 Emissions
# 1     7.0                  8.6                  33         199
# 2     9.0                 10.8                  26         252
# 3     9.5                 11.0                  26         258
# 4     9.0                  9.0                  31         210
# 5    10.8                 11.0                  26         261
# 6     8.6                  9.9                  29         232
# 7     9.1                 10.3                  27         242
# 8     8.2                  8.4                  34         196
# 9     7.1                  8.7                  32         205
# 10    7.4                  8.9                  32         209
# 11    7.7                  9.8                  29         228
# 12    8.2                 10.3                  27         240
# 13    6.9                  8.4                  34         197
# 14    6.9                  8.4                  34         197
# 15    7.2                  8.7                  32         205
# 16    7.7                  9.2                  31         217
# 17    9.6                 11.9                  24         280
# 18    8.1                  9.3                  30         218
# 19    8.3                  9.6                  29         226
# 20   10.4                 12.4                  23         292
# 21    9.8                 11.5                  25         271
# 22   10.6                 13.3                  21         312
# 23   10.7                 13.8                  20         324
# 24   10.9                 14.1                  20         332
# 25   11.4                 14.7                  19         346
# 26    9.4                 11.2                  25         264
# 27    6.8                  8.1                  35         188
# 28    7.9                  9.6                  29         225
# 29    7.9                  9.5                  30         221
# 30    6.9                  7.8                  36         182
# ...  ...                  ...                   ...        ...
# 1253 NA                   NA                    NA         NA
# 1254 NA                   NA                    NA         NA
# 1255 NA                   NA                    NA         NA
# 1256 NA                   NA                    NA         NA
# 1257 NA                   NA                    NA         NA
# 1258 NA                   NA                    NA         NA
# 1259 NA                   NA                    NA         NA
# 1260 NA                   NA                    NA         NA
# 1261 NA                   NA                    NA         NA
# 1262 NA                   NA                    NA         NA
# 1263 NA                   NA                    NA         NA
# 1264 NA                   NA                    NA         NA
# 1265 NA                   NA                    NA         NA
# 1266 NA                   NA                    NA         NA
# 1267 NA                   NA                    NA         NA
# 1268 NA                   NA                    NA         NA
# 1269 NA                   NA                    NA         NA
# 1270 NA                   NA                    NA         NA
# 1271 NA                   NA                    NA         NA
# 1272 NA                   NA                    NA         NA
# 1273 NA                   NA                    NA         NA
# 1274 NA                   NA                    NA         NA
# 1275 NA                   NA                    NA         NA
# 1276 NA                   NA                    NA         NA
# 1277 NA                   NA                    NA         NA
# 1278 NA                   NA                    NA         NA
# 1279 NA                   NA                    NA         NA
# 1280 NA                   NA                    NA         NA
# 1281 NA                   NA                    NA         NA
# 1282 NA                   NA                    NA         NA
#      CO2 Rating Smog Rating
# 1    6          3
# 2    4          3
# 3    4          3
# 4    5          3
# 5    4          3
# 6    5          6
# 7    5          6
# 8    6          7
# 9    6          3
# 10   5          3
# 11   5          3
# 12   5          3
# 13   6          1
# 14   6          1
# 15   6          3
# 16   5          3
# 17   4          3
# 18   5          3
# 19   5          3
# 20   3          3
# 21   4          3
# 22   3          3
# 23   3          3
# 24   3          3
# 25   2          3
# 26   4          3
# 27   6          7
# 28   5          7
# 29   5          7
# 30   7          5
# ...  ...        ...
# 1253 NA         NA
# 1254 NA         NA
# 1255 NA         NA
# 1256 NA         NA
# 1257 NA         NA
# 1258 NA         NA
# 1259 NA         NA
# 1260 NA         NA
# 1261 NA         NA
# 1262 NA         NA
# 1263 NA         NA
# 1264 NA         NA
# 1265 NA         NA
# 1266 NA         NA
# 1267 NA         NA
# 1268 NA         NA
# 1269 NA         NA
# 1270 NA         NA
# 1271 NA         NA
# 1272 NA         NA
# 1273 NA         NA
# 1274 NA         NA
# 1275 NA         NA
# 1276 NA         NA
# 1277 NA         NA
# 1278 NA         NA
# 1279 NA         NA
# 1280 NA         NA
# 1281 NA         NA
# 1282 NA         NA

# %%
read_csv("downloads/MY2000 Fuel Consumption Ratings 5-cycle.csv", col_names=newer_colnames, skip=3)
# Out:
# Parsed with column specification:
# cols(
#   Year = col_character(),
#   Make = col_character(),
#   Model = col_character(),
#   Class = col_character(),
#   `Engine Size` = col_double(),
#   Cylinders = col_integer(),
#   Transmission = col_character(),
#   `Fuel Type` = col_character(),
#   `Fuel Consumption City` = col_double(),
#   `Fuel Consumption Hwy` = col_double(),
#   `Fuel Consumption Comb` = col_double(),
#   `Comb (mpg)` = col_integer(),
#   `CO2 Emissions` = col_integer(),
#   `CO2 Rating` = col_character(),
#   `Smog Rating` = col_character()
# )
# Warning message in rbind(names(probs), probs_f):
# "number of columns of result is not a multiple of vector length (arg 1)"Warning message:
# "664 parsing failures.
# row # A tibble: 5 x 5 col     row col   expected   actual     file                                        expected   <int> <chr> <chr>      <chr>      <chr>                                       actual 1     1 <NA>  15 columns 13 columns 'downloads/MY2000 Fuel Consumption Ratings~ file 2     2 <NA>  15 columns 13 columns 'downloads/MY2000 Fuel Consumption Ratings~ row 3     3 <NA>  15 columns 13 columns 'downloads/MY2000 Fuel Consumption Ratings~ col 4     4 <NA>  15 columns 13 columns 'downloads/MY2000 Fuel Consumption Ratings~ expected 5     5 <NA>  15 columns 13 columns 'downloads/MY2000 Fuel Consumption Ratings~
# ... ................. ... ............................................................................... ........ ............................................................................... ...... ............................................................................... .... ............................................................................... ... ............................................................................... ... ............................................................................... ........ ...............................................................................
# See problems(...) for more details.
# "
#     Year
# 1   2000
# 2   2000
# 3   2000
# 4   2000
# 5   2000
# 6   2000
# 7   2000
# 8   2000
# 9   2000
# 10  2000
# 11  2000
# 12  2000
# 13  2000
# 14  2000
# 15  2000
# 16  2000
# 17  2000
# 18  2000
# 19  2000
# 20  2000
# 21  2000
# 22  2000
# 23  2000
# 24  2000
# 25  2000
# 26  2000
# 27  2000
# 28  2000
# 29  2000
# 30  2000
# ... ...
# 635 2000
# 636 2000
# 637 2000
# 638 2000
# 639 2000
# 640 NA
# 641 *Starting with the 2015 model year, vehicle manufacturers will use an improved testing procedure to determine the fuel consumption ratings of new light-duty vehicles. The new test methods result in higher fuel consumption ratings that are
# 642 more representative of everyday driving. To help you compare vehicles from different model years, the ratings for 1995-2014 vehicles have been adjusted to reflect the new test methods. Note that these  are approximate values that were
# 643 generated from the original ratings, not from vehicle testing.
# 644 NA
# 645 Understanding the Table
# 646 Model
# 647 NA
# 648 NA
# 649 NA
# 650 NA
# 651 NA
# 652 Transmission
# 653 NA
# 654 NA
# 655 NA
# 656 NA
# 657 NA
# 658 Fuel Type
# 659 NA
# 660 NA
# 661 NA
# 662 NA
# 663 Fuel Consumption
# 664 CO2 Emissions (g/km)
#     Make
# 1   ACURA
# 2   ACURA
# 3   ACURA
# 4   ACURA
# 5   ACURA
# 6   ACURA
# 7   ACURA
# 8   ACURA
# 9   ACURA
# 10  AUDI
# 11  AUDI
# 12  AUDI
# 13  AUDI
# 14  AUDI
# 15  AUDI
# 16  AUDI
# 17  AUDI
# 18  AUDI
# 19  AUDI
# 20  AUDI
# 21  AUDI
# 22  AUDI
# 23  AUDI
# 24  AUDI
# 25  AUDI
# 26  AUDI
# 27  AUDI
# 28  AUDI
# 29  AUDI
# 30  AUDI
# ... ...
# 635 VOLVO
# 636 VOLVO
# 637 VOLVO
# 638 VOLVO
# 639 VOLVO
# 640 NA
# 641 NA
# 642 NA
# 643 NA
# 644 NA
# 645 NA
# 646 4WD/4X4 = Four-wheel drive
# 647 AWD = All-wheel drive
# 648 CNG = Compressed natural gas
# 649 FFV = Flexible-fuel vehicle
# 650 NGV = Natural gas vehicle
# 651 # = High output engine that provides more power than the standard engine of the same size
# 652 A = Automatic
# 653 AM = Automated manual
# 654 AS = Automatic with select shift
# 655 AV = Continuously variable
# 656 M = Manual
# 657 3 <U+0096> 10 = Number of gears
# 658 X = Regular gasoline
# 659 Z = Premium gasoline
# 660 D = Diesel
# 661 E = Ethanol (E85)
# 662 N = Natural Gas
# 663 City and highway fuel consumption ratings are shown in litres per 100 kilometres (L/100 km) - combined rating (55% city, 45% hwy) is shown in L/100 km and in miles per imperial gallon (mpg)
# 664 Estimated tailpipe carbon dioxide emissions (in grams per kilometre) are based on fuel type and the combined fuel consumption rating.
#     Model                           Class                    Engine Size
# 1   1.6EL                           COMPACT                  1.6
# 2   1.6EL                           COMPACT                  1.6
# 3   3.2TL                           MID-SIZE                 3.2
# 4   3.5RL                           MID-SIZE                 3.5
# 5   INTEGRA                         SUBCOMPACT               1.8
# 6   INTEGRA                         SUBCOMPACT               1.8
# 7   INTEGRA GSR/TYPE R              SUBCOMPACT               1.8
# 8   NSX                             SUBCOMPACT               3.0
# 9   NSX                             SUBCOMPACT               3.2
# 10  A4                              COMPACT                  1.8
# 11  A4                              COMPACT                  1.8
# 12  A4                              COMPACT                  2.8
# 13  A4                              COMPACT                  2.8
# 14  A4 QUATTRO                      COMPACT                  1.8
# 15  A4 QUATTRO                      COMPACT                  1.8
# 16  A4 QUATTRO                      COMPACT                  2.8
# 17  A4 QUATTRO                      COMPACT                  2.8
# 18  A6                              MID-SIZE                 2.8
# 19  A6 AVANT QUATTRO                STATION WAGON - MID-SIZE 2.8
# 20  A6 QUATTRO                      MID-SIZE                 2.7
# 21  A6 QUATTRO                      MID-SIZE                 2.7
# 22  A6 QUATTRO                      MID-SIZE                 2.8
# 23  A6 QUATTRO                      MID-SIZE                 2.8
# 24  A6 QUATTRO                      MID-SIZE                 4.2
# 25  A8 QUATTRO                      MID-SIZE                 4.2
# 26  S4 QUATTRO                      COMPACT                  2.7
# 27  S4 QUATTRO                      COMPACT                  2.7
# 28  TT COUPE QUATTRO                MINICOMPACT              1.8
# 29  TT COUPE QUATTRO (SUPERCHARGED) MINICOMPACT              1.8
# 30  TT ROADSTER                     TWO-SEATER               1.8
# ... ...                             ...                      ...
# 635 V70 AWD TURBO                   STATION WAGON - MID-SIZE 2.4
# 636 V70 GLT TURBO                   STATION WAGON - MID-SIZE 2.4
# 637 V70 T5 TURBO                    STATION WAGON - MID-SIZE 2.3
# 638 V70 T5 TURBO                    STATION WAGON - MID-SIZE 2.3
# 639 V70R AWD TURBO                  STATION WAGON - MID-SIZE 2.4
# 640 NA                              NA                        NA
# 641 NA                              NA                        NA
# 642 NA                              NA                        NA
# 643 NA                              NA                        NA
# 644 NA                              NA                        NA
# 645 NA                              NA                        NA
# 646 NA                              NA                        NA
# 647 NA                              NA                        NA
# 648 NA                              NA                        NA
# 649 NA                              NA                        NA
# 650 NA                              NA                        NA
# 651 NA                              NA                        NA
# 652 NA                              NA                        NA
# 653 NA                              NA                        NA
# 654 NA                              NA                        NA
# 655 NA                              NA                        NA
# 656 NA                              NA                        NA
# 657 NA                              NA                        NA
# 658 NA                              NA                        NA
# 659 NA                              NA                        NA
# 660 NA                              NA                        NA
# 661 NA                              NA                        NA
# 662 NA                              NA                        NA
# 663 NA                              NA                        NA
# 664 NA                              NA                        NA
#     Cylinders Transmission Fuel Type Fuel Consumption City Fuel Consumption Hwy
# 1   4         A4           X         10.5                   8.0
# 2   4         M5           X          9.8                   7.8
# 3   6         AS5          Z         13.7                   8.8
# 4   6         A4           Z         15.0                  10.9
# 5   4         A4           X         11.4                   8.3
# 6   4         M5           X         10.6                   8.1
# 7   4         M5           Z         10.8                   8.3
# 8   6         AS4          Z         15.2                  10.9
# 9   6         M6           Z         15.4                  10.7
# 10  4         A5           Z         12.9                   8.6
# 11  4         M5           Z         11.1                   8.1
# 12  6         A5           Z         14.6                   9.7
# 13  6         M5           Z         13.2                   8.9
# 14  4         A5           Z         13.6                   9.1
# 15  4         M5           Z         12.1                   8.9
# 16  6         A5           Z         14.9                  10.1
# 17  6         M5           Z         14.3                  10.3
# 18  6         A5           Z         15.0                  10.2
# 19  6         A5           Z         15.4                  10.7
# 20  6         A5           Z         15.2                  10.6
# 21  6         M6           Z         15.2                  10.7
# 22  6         A5           Z         15.4                  10.7
# 23  6         M5           Z         14.6                  10.9
# 24  8         A5           Z         15.5                  10.7
# 25  8         A5           Z         15.5                  10.7
# 26  6         A5           Z         15.2                  10.6
# 27  6         M6           Z         15.2                  10.7
# 28  4         M5           Z         13.1                   9.0
# 29  4         M6           Z         13.1                   9.1
# 30  4         M5           Z         12.3                   8.7
# ... ...       ...          ...       ...                   ...
# 635  5        A4           Z         14.4                  10.3
# 636  5        A4           Z         13.6                   9.7
# 637  5        A4           Z         13.9                   9.5
# 638  5        M5           Z         13.0                   9.3
# 639  5        A5           Z         14.7                  10.9
# 640 NA        NA           NA          NA                    NA
# 641 NA        NA           NA          NA                    NA
# 642 NA        NA           NA          NA                    NA
# 643 NA        NA           NA          NA                    NA
# 644 NA        NA           NA          NA                    NA
# 645 NA        NA           NA          NA                    NA
# 646 NA        NA           NA          NA                    NA
# 647 NA        NA           NA          NA                    NA
# 648 NA        NA           NA          NA                    NA
# 649 NA        NA           NA          NA                    NA
# 650 NA        NA           NA          NA                    NA
# 651 NA        NA           NA          NA                    NA
# 652 NA        NA           NA          NA                    NA
# 653 NA        NA           NA          NA                    NA
# 654 NA        NA           NA          NA                    NA
# 655 NA        NA           NA          NA                    NA
# 656 NA        NA           NA          NA                    NA
# 657 NA        NA           NA          NA                    NA
# 658 NA        NA           NA          NA                    NA
# 659 NA        NA           NA          NA                    NA
# 660 NA        NA           NA          NA                    NA
# 661 NA        NA           NA          NA                    NA
# 662 NA        NA           NA          NA                    NA
# 663 NA        NA           NA          NA                    NA
# 664 NA        NA           NA          NA                    NA
#     Fuel Consumption Comb Comb (mpg) CO2 Emissions CO2 Rating Smog Rating
# 1    9.4                  30         216           NA         NA
# 2    8.9                  32         205           NA         NA
# 3   11.5                  25         265           NA         NA
# 4   13.1                  22         301           NA         NA
# 5   10.0                  28         230           NA         NA
# 6    9.5                  30         219           NA         NA
# 7    9.7                  29         223           NA         NA
# 8   13.3                  21         306           NA         NA
# 9   13.3                  21         306           NA         NA
# 10  10.9                  26         251           NA         NA
# 11   9.7                  29         223           NA         NA
# 12  12.4                  23         285           NA         NA
# 13  11.3                  25         260           NA         NA
# 14  11.6                  24         267           NA         NA
# 15  10.7                  26         246           NA         NA
# 16  12.7                  22         292           NA         NA
# 17  12.5                  23         288           NA         NA
# 18  12.8                  22         294           NA         NA
# 19  13.3                  21         306           NA         NA
# 20  13.2                  21         304           NA         NA
# 21  13.2                  21         304           NA         NA
# 22  13.3                  21         306           NA         NA
# 23  12.9                  22         297           NA         NA
# 24  13.4                  21         308           NA         NA
# 25  13.4                  21         308           NA         NA
# 26  13.2                  21         304           NA         NA
# 27  13.2                  21         304           NA         NA
# 28  11.3                  25         260           NA         NA
# 29  11.3                  25         260           NA         NA
# 30  10.7                  26         246           NA         NA
# ... ...                   ...        ...           ...        ...
# 635 12.5                  23         288           NA         NA
# 636 11.9                  24         274           NA         NA
# 637 11.9                  24         274           NA         NA
# 638 11.3                  25         260           NA         NA
# 639 13.0                  22         299           NA         NA
# 640   NA                  NA          NA           NA         NA
# 641   NA                  NA          NA           NA         NA
# 642   NA                  NA          NA           NA         NA
# 643   NA                  NA          NA           NA         NA
# 644   NA                  NA          NA           NA         NA
# 645   NA                  NA          NA           NA         NA
# 646   NA                  NA          NA           NA         NA
# 647   NA                  NA          NA           NA         NA
# 648   NA                  NA          NA           NA         NA
# 649   NA                  NA          NA           NA         NA
# 650   NA                  NA          NA           NA         NA
# 651   NA                  NA          NA           NA         NA
# 652   NA                  NA          NA           NA         NA
# 653   NA                  NA          NA           NA         NA
# 654   NA                  NA          NA           NA         NA
# 655   NA                  NA          NA           NA         NA
# 656   NA                  NA          NA           NA         NA
# 657   NA                  NA          NA           NA         NA
# 658   NA                  NA          NA           NA         NA
# 659   NA                  NA          NA           NA         NA
# 660   NA                  NA          NA           NA         NA
# 661   NA                  NA          NA           NA         NA
# 662   NA                  NA          NA           NA         NA
# 663   NA                  NA          NA           NA         NA
# 664   NA                  NA          NA           NA         NA

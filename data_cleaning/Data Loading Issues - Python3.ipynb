# %% [markdown]
# # Data Loading Issues with Python
#
# This notebook demonstrates data cleaning principles in Python. First we take a look at some encoding issues using a contrived example, and then we work through an example of loading some data as published on the Open Data portal. Note that this example is constructed with Python 3, which uses UTF8 encodings by default as a major difference from Python 2. There is also a similar notebook focused on R.
#
# - [Part 1: Encoding Issues](#Encoding-Issues)
# - [Part 2: Example: Open Data](#Example:-Open-Data)

# %%
# %matplotlib inline

import requests
import os
import urllib.parse
import re

import pandas as pd     
import numpy as np

# %% [markdown]
# # Encoding Issues
# Computers ultimately represent everything as a number, and over time, different operating systems, and different languages there have been many ways of representing text. Most encodings (except for ones designed specifically for Asian languages) are extensions of ASCII, which was designed for English, so the English alphabet and most common punctuation characters are usually not a problem, but ASCII does not include things like accented characters for French.
#
# To demonstrate some of the potential issues, I made a file in Notepad and saved it using the default ANSI encoding (this default is changing to UTF8 as of the May 2019 update of Windows 10). This shows French text with accents, and non-ASCII punctuation characters. This formatting is similar to Excel's settings when used in French to generate a CSV file - it uses a ; instead of , for the delimiter as , is the decimal separator.
#
# ```
# DEPARTEMENT;DÉPENSES;Punctuation
# Administration du pipe-line du Nord;123456,88;“–”
# Agence canadienne d’évaluation environnementale;999999,24;†•
# Agence de développement économique du Canada pour les régions du Québec;234567,00;€
# ```
#
# ## Issue 1: Can't read the file at all with UnicodeDecodeError

# %%
# This will produce the error "UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc9 in position 1: invalid continuation byte"
try:
    pd.read_csv('NotepadFrench.csv')
except UnicodeDecodeError as error:
    print(error)
# Out:
# 'utf-8' codec can't decode byte 0xc9 in position 13: invalid continuation byte

# %% [markdown]
# In order to fix the UnicodeDecodeError, you need to determine the right encoding to load the file. There are many possibilities, fully documented here: https://docs.python.org/3/library/codecs.html#standard-encodings.
#
# ## Issue 2: Not all characters loaded properly - missing values and mojibake
# `latin-1` (also known as `ISO-8859-1`) is a common encoding for Western European text including French, but it's not showing the advanced punctuation characters as they map to unprintable control characters (though they are there, as demonstrated by computing the length of the string).

# %%
no_punctuation = pd.read_csv('NotepadFrench.csv', sep=";", encoding="latin-1")
no_punctuation["Punctuation Length"] = no_punctuation["Punctuation"].str.len()
no_punctuation
# Out:
#                                          DEPARTEMENT   DÉPENSES Punctuation  \
# 0                Administration du pipe-line du Nord  123456,88         
# 1    Agence canadienne dévaluation environnementale  999999,24          
# 2  Agence de développement économique du Canada p...  234567,00           
#
#    Punctuation Length
# 0                   3
# 1                   2
# 2                   1

# %% [markdown]
# Another possibility is that characters map to incorrect visible characters. Here we attempt to load it using IBM863, 'MS-DOS French Canada', which was used by MS-DOS systems in Canada.

# %%
pd.read_csv('NotepadFrench.csv', sep=";", encoding="IBM863")
# Out:
#                                          DEPARTEMENT   D╔PENSES Punctuation
# 0                Administration du pipe-line du Nord  123456,88         ôûË
# 1    Agence canadienne dÊΘvaluation environnementale  999999,24          ¶Ï
# 2  Agence de dΘveloppement Θconomique du Canada p...  234567,00           Ç

# %% [markdown]
# `windows-1252` is a Windows specific superset of `ISO-8859-1` which includes several additional characters. It is one of several different 'ANSI Codepages' for representing different languages. This is the most likely option if a file was created on a Windows system in English, French, or most Western European languages.

# %%
wrong_decimal = pd.read_csv('NotepadFrench.csv', sep=";", encoding="windows-1252")
wrong_decimal
# Out:
#                                          DEPARTEMENT   DÉPENSES Punctuation
# 0                Administration du pipe-line du Nord  123456,88         “–”
# 1    Agence canadienne d’évaluation environnementale  999999,24          †•
# 2  Agence de développement économique du Canada p...  234567,00           €

# %% [markdown]
# While not strictly an encoding issue, one other issue with dealing with multiple languages is different localization settings like date formats and decimal separators. `DÉPENSES` has been read in as text rather than a number as Pandas expects a . not , by default.

# %%
wrong_decimal["DÉPENSES"].sum()
# Out:
# '123456,88999999,24234567,00'

# %%
correct_sample = pd.read_csv('NotepadFrench.csv', sep=";", encoding="windows-1252", decimal=",")
correct_sample
# Out:
#                                          DEPARTEMENT   DÉPENSES Punctuation
# 0                Administration du pipe-line du Nord  123456.88         “–”
# 1    Agence canadienne d’évaluation environnementale  999999.24          †•
# 2  Agence de développement économique du Canada p...  234567.00           €

# %%
correct_sample["DÉPENSES"].sum()
# Out:
# 1358023.12

# %% [markdown]
# Here we save a version of the file which plays nicely with Pandas defaults.

# %%
correct_sample.to_csv('utf8French.csv', index=False)
pd.read_csv('utf8French.csv')
# Out:
#                                          DEPARTEMENT   DÉPENSES Punctuation
# 0                Administration du pipe-line du Nord  123456.88         “–”
# 1    Agence canadienne d’évaluation environnementale  999999.24          †•
# 2  Agence de développement économique du Canada p...  234567.00           €

# %% [markdown]
# ## Issue 3: Loading UTF8 into Excel
#
# Excel defaults to the ANSI codepage used by the operating system (e.g. Windows-1252), and will not properly load UTF8 text via File->Open.
#
# The solution is to import the text into Excel instead and choose the appropriate encoding.
# ![Loading UTF8 into Excel using Text Import](ExcelImport.png)

# %%
pd.read_csv('utf8French.csv', encoding="ansi")
# Out:
#                                          DEPARTEMENT  DÃ‰PENSES Punctuation
# 0                Administration du pipe-line du Nord  123456.88   â€œâ€“â€
# 1  Agence canadienne dâ€™Ã©valuation environnemen...  999999.24      â€ â€¢
# 2  Agence de dÃ©veloppement Ã©conomique du Canada...  234567.00         â‚¬

# %% [markdown]
# # Example: Open Data
# Fuel consumption ratings (NRCAN): https://open.canada.ca/data/en/dataset/98f1a129-f628-4ce4-b24d-6f16bf24dd64
#
# In this scenario, I want to do some analysis on a dataset published to the open data portal. This dataset is spread over multiple files for different years, and there are some minor changes to the columns over time. Like many datasets on Open Data it has some features which make it easier for people to look at but harder for machines - the column names are formatted over two rows, and there is some extra descriptions of fields below the main data section. A bit more unusually, it also has extra blank lines between rows and for some years, there are lots of extra blank columns and rows at the end.
#
# First I wrote some code to download all the files matching a specific pattern because there's a lot of them. To start, I am downloading all of the English Fuel Consumption Ratings files for gas cars.

# %%
def download_files(pattern):
    # Get all the CSV files associated with this dataset that match the pattern
    info_response = requests.get("https://open.canada.ca/data/api/action/package_show?id=98f1a129-f628-4ce4-b24d-6f16bf24dd64")
    dataset_info = info_response.json()
    print(dataset_info["result"]["notes_translated"]["en"])
    files = []
    directory = "downloads"
    if not os.path.exists(directory):
        os.mkdir(directory)
    en_gas_re = re.compile(pattern)
    
    for resource in dataset_info["result"]["resources"]:
        if resource['format'] == 'CSV':
            fname = os.path.basename(resource['url']) # Get just the filename
            fname = urllib.parse.unquote(fname) # The URLs will have things like %20 for spaces, this cleans it up
            if en_gas_re.match(fname) is not None:
                fname = os.path.join(directory, fname)
                files.append(fname)
                if not os.path.exists(fname):
                    print('Downloading ' + resource['name'] + ' from ' + resource['url'])
                    response = requests.get(resource['url'])
                    with open(fname, "w", encoding='utf8') as csvfile:
                        csvfile.write(response.text)
    return files

# %%
en_consumption_files = download_files("MY[0-9]{4} Fuel Consumption Ratings.*csv")
# Out:
# Datasets provide model-specific fuel consumption ratings and estimated carbon dioxide emissions for new light-duty vehicles for retail sale in Canada.
#
# To help you compare vehicles from different model years, the fuel consumption ratings for 1995 to 2014 vehicles have been adjusted to reflect the improved testing that is more representative of everyday driving. Note that these are approximate values that were generated from the original ratings, not from vehicle testing.
#
# For more information on fuel consumption testing, visit: https://www.nrcan.gc.ca/energy/efficiency/transportation/21008.
#
# To compare the fuel consumption information of 1995 to 2019 model year vehicles, use the fuel consumption ratings search tool at https://fcr-ccc.nrcan-rncan.gc.ca/en.
#
# (Data update: June 27, 2019)

# %% [markdown]
# ## Cleaning up just the most recent year step by step
# In this section, I go through the steps to look at and fix issues with one file.

# %%
data = pd.read_csv("downloads/MY2019 Fuel Consumption Ratings.csv")
data.head()
# Out:
#   Model   Make            Model.1 Vehicle Class Engine Size  Cylinders  \
# 0  Year    NaN                NaN           NaN         (L)        NaN
# 1  2019  Acura                ILX       Compact         2.4        4.0
# 2  2019  Acura         MDX SH-AWD    SUV: Small         3.5        6.0
# 3  2019  Acura  MDX SH-AWD A-SPEC    SUV: Small         3.5        6.0
# 4  2019  Acura     MDX Hybrid AWD    SUV: Small         3.0        6.0
#
#   Transmission  Fuel Fuel Consumption      Unnamed: 9      ...       \
# 0          NaN  Type  City (L/100 km)  Hwy (L/100 km)      ...
# 1          AM8     Z              9.9             7.0      ...
# 2          AS9     Z             12.2             9.0      ...
# 3          AS9     Z             12.2             9.5      ...
# 4          AM7     Z              9.1             9.0      ...
#
#   Unnamed: 211 Unnamed: 212 Unnamed: 213 Unnamed: 214 Unnamed: 215  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 216  Unnamed: 217  Unnamed: 218  Unnamed: 219  Unnamed: 220
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
# [5 rows x 221 columns]

# %%
data.tail()
# Out:
#      Model Make Model.1 Vehicle Class Engine Size  Cylinders Transmission  \
# 1278   NaN  NaN     NaN           NaN         NaN        NaN          NaN
# 1279   NaN  NaN     NaN           NaN         NaN        NaN          NaN
# 1280   NaN  NaN     NaN           NaN         NaN        NaN          NaN
# 1281   NaN  NaN     NaN           NaN         NaN        NaN          NaN
# 1282   NaN  NaN     NaN           NaN         NaN        NaN          NaN
#
#      Fuel Fuel Consumption Unnamed: 9      ...      Unnamed: 211 Unnamed: 212  \
# 1278  NaN              NaN        NaN      ...               NaN          NaN
# 1279  NaN              NaN        NaN      ...               NaN          NaN
# 1280  NaN              NaN        NaN      ...               NaN          NaN
# 1281  NaN              NaN        NaN      ...               NaN          NaN
# 1282  NaN              NaN        NaN      ...               NaN          NaN
#
#      Unnamed: 213 Unnamed: 214 Unnamed: 215  Unnamed: 216  Unnamed: 217  \
# 1278          NaN          NaN          NaN           NaN           NaN
# 1279          NaN          NaN          NaN           NaN           NaN
# 1280          NaN          NaN          NaN           NaN           NaN
# 1281          NaN          NaN          NaN           NaN           NaN
# 1282          NaN          NaN          NaN           NaN           NaN
#
#       Unnamed: 218  Unnamed: 219  Unnamed: 220
# 1278           NaN           NaN           NaN
# 1279           NaN           NaN           NaN
# 1280           NaN           NaN           NaN
# 1281           NaN           NaN           NaN
# 1282           NaN           NaN           NaN
#
# [5 rows x 221 columns]

# %% [markdown]
# Looking at the top and the bottom of the file, I see that there are a lot of columns that look to be empty, and also a lot of empty rows at the bottom.
#
# ### Identify and drop the extra columns
# Looking at the count() of a column tells us how many values are not NaN. Here we see many columns with count() of 0

# %%
data.count()
# Out:
# Model               1031
# Make                1043
# Model.1             1022
# Vehicle Class       1022
# Engine Size         1023
# Cylinders           1022
# Transmission        1022
# Fuel                1023
# Fuel Consumption    1023
# Unnamed: 9          1023
# Unnamed: 10         1023
# Unnamed: 11         1023
# CO2 Emissions       1023
# CO2                 1023
# Smog                1023
# Unnamed: 15            0
# Unnamed: 16            0
# Unnamed: 17            0
# Unnamed: 18            0
# Unnamed: 19            0
# Unnamed: 20            0
# Unnamed: 21            0
# Unnamed: 22            0
# Unnamed: 23            0
# Unnamed: 24            0
# Unnamed: 25            0
# Unnamed: 26            0
# Unnamed: 27            0
# Unnamed: 28            0
# Unnamed: 29            0
#                     ...
# Unnamed: 191           0
# Unnamed: 192           0
# Unnamed: 193           0
# Unnamed: 194           0
# Unnamed: 195           0
# Unnamed: 196           0
# Unnamed: 197           0
# Unnamed: 198           0
# Unnamed: 199           0
# Unnamed: 200           0
# Unnamed: 201           0
# Unnamed: 202           0
# Unnamed: 203           0
# Unnamed: 204           0
# Unnamed: 205           0
# Unnamed: 206           0
# Unnamed: 207           0
# Unnamed: 208           0
# Unnamed: 209           0
# Unnamed: 210           0
# Unnamed: 211           0
# Unnamed: 212           0
# Unnamed: 213           0
# Unnamed: 214           0
# Unnamed: 215           0
# Unnamed: 216           0
# Unnamed: 217           0
# Unnamed: 218           0
# Unnamed: 219           0
# Unnamed: 220           0
# Length: 221, dtype: int64

# %%
def drop_empty_columns(data):
    empty_columns = data.count() == 0 # Get a list of the columns with no data
    empty_columns = empty_columns[empty_columns].index
    return data.drop(columns=empty_columns)
data = drop_empty_columns(data)
data.columns
# Out:
# Index(['Model', 'Make', 'Model.1', 'Vehicle Class', 'Engine Size', 'Cylinders',
#        'Transmission', 'Fuel', 'Fuel Consumption', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'CO2 Emissions', 'CO2', 'Smog'],
#       dtype='object')

# %% [markdown]
# ### Update the column names
# Since the column names are spread over multiple rows, some of the automatically inferred column names aren't very helpful. In this case we can copy the output from the column above into the code and use it as a start rather than retyping everything.

# %%
columns = ['Year', 'Make', 'Model', 'Class', 'Engine Size',
        'Cylinders', 'Transmission', 'Fuel Type',
        'Fuel Consumption City', 'Fuel Consumption Hwy', 'Fuel Consumption Comb',
        'Comb (mpg)', 'CO2 Emissions', 'CO2 Rating', 'Smog Rating']
data.columns = columns

# %% [markdown]
# ### Drop rows which aren't data rows
#
# In this dataset, there are rows at the bottom which have some explanations spread over a couple columns. Let's drop everything that doesn't have at least 5 non-NA values to be safe. Be careful as this could drop rows containing missing data, but that isn't a problem with these files. The first row has more than 5 non-NA value so we'll drop it separately.
#
# If we wanted to drop only rows that are completely empty, we could use `data.dropna(axis=0, how='all')`. Setting `how='any'` would drop rows where anything is missing. You can also drop specific rows by index using `data.drop(0)`

# %%
data.dropna(thresh=5)
# Out:
#       Year          Make                     Model                    Class  \
# 0     Year           NaN                       NaN                      NaN
# 1     2019         Acura                       ILX                  Compact
# 2     2019         Acura                MDX SH-AWD               SUV: Small
# 3     2019         Acura         MDX SH-AWD A-SPEC               SUV: Small
# 4     2019         Acura            MDX Hybrid AWD               SUV: Small
# 5     2019         Acura                       NSX               Two-seater
# 6     2019         Acura                   RDX AWD               SUV: Small
# 7     2019         Acura            RDX AWD A-SPEC               SUV: Small
# 8     2019         Acura                RLX Hybrid                 Mid-size
# 9     2019         Acura                       TLX                  Compact
# 10    2019         Acura                TLX A-SPEC                  Compact
# 11    2019         Acura                TLX SH-AWD                  Compact
# 12    2019         Acura         TLX SH-AWD A-SPEC                  Compact
# 13    2019    Alfa Romeo                  4C Coupe               Two-seater
# 14    2019    Alfa Romeo                 4C Spider               Two-seater
# 15    2019    Alfa Romeo                    Giulia                 Mid-size
# 16    2019    Alfa Romeo                Giulia AWD                 Mid-size
# 17    2019    Alfa Romeo       Giulia Quadrifoglio                 Mid-size
# 18    2019    Alfa Romeo                   Stelvio               SUV: Small
# 19    2019    Alfa Romeo               Stelvio AWD               SUV: Small
# 20    2019    Alfa Romeo  Stelvio AWD Quadrifoglio               SUV: Small
# 21    2019  Aston Martin                   DB11 V8              Minicompact
# 22    2019  Aston Martin                  DB11 AMR              Minicompact
# 23    2019  Aston Martin          DBS Superleggera              Minicompact
# 24    2019  Aston Martin                Rapide AMR               Subcompact
# 25    2019  Aston Martin           Vanquish Zagato              Minicompact
# 26    2019  Aston Martin                Vantage V8               Two-seater
# 27    2019          Audi                        A3               Subcompact
# 28    2019          Audi                A3 quattro               Subcompact
# 29    2019          Audi      A3 Cabriolet quattro               Subcompact
# ...    ...           ...                       ...                      ...
# 993   2019    Volkswagen                  Golf GTI                  Compact
# 994   2019    Volkswagen                    Golf R                  Compact
# 995   2019    Volkswagen                    Golf R                  Compact
# 996   2019    Volkswagen             Golf Alltrack     Station wagon: Small
# 997   2019    Volkswagen             Golf Alltrack     Station wagon: Small
# 998   2019    Volkswagen           Golf SportWagen     Station wagon: Small
# 999   2019    Volkswagen           Golf SportWagen     Station wagon: Small
# 1000  2019    Volkswagen   Golf SportWagen 4MOTION     Station wagon: Small
# 1001  2019    Volkswagen   Golf SportWagen 4MOTION     Station wagon: Small
# 1002  2019    Volkswagen                     Jetta                  Compact
# 1003  2019    Volkswagen                     Jetta                  Compact
# 1004  2019    Volkswagen                 Jetta GLI                  Compact
# 1005  2019    Volkswagen                 Jetta GLI                  Compact
# 1006  2019    Volkswagen                    Passat                 Mid-size
# 1007  2019    Volkswagen                    Tiguan               SUV: Small
# 1008  2019    Volkswagen            Tiguan 4MOTION               SUV: Small
# 1009  2019         Volvo                    S60 T5                  Compact
# 1010  2019         Volvo                S60 T6 AWD                  Compact
# 1011  2019         Volvo                S90 T5 AWD                 Mid-size
# 1012  2019         Volvo                S90 T6 AWD                 Mid-size
# 1013  2019         Volvo                    V60 T5     Station wagon: Small
# 1014  2019         Volvo                V60 T6 AWD     Station wagon: Small
# 1015  2019         Volvo             V60 CC T5 AWD     Station wagon: Small
# 1016  2019         Volvo                V90 T6 AWD  Station wagon: Mid-size
# 1017  2019         Volvo             V90 CC T6 AWD  Station wagon: Mid-size
# 1018  2019         Volvo               XC40 T5 AWD               SUV: Small
# 1019  2019         Volvo               XC60 T5 AWD               SUV: Small
# 1020  2019         Volvo               XC60 T6 AWD               SUV: Small
# 1021  2019         Volvo               XC90 T5 AWD            SUV: Standard
# 1022  2019         Volvo               XC90 T6 AWD            SUV: Standard
#
#      Engine Size  Cylinders Transmission Fuel Type Fuel Consumption City  \
# 0            (L)        NaN          NaN      Type       City (L/100 km)
# 1            2.4        4.0          AM8         Z                   9.9
# 2            3.5        6.0          AS9         Z                  12.2
# 3            3.5        6.0          AS9         Z                  12.2
# 4            3.0        6.0          AM7         Z                   9.1
# 5            3.5        6.0          AM9         Z                  11.1
# 6            2.0        4.0         AS10         Z                  11.0
# 7            2.0        4.0         AS10         Z                  11.3
# 8            3.5        6.0          AM7         Z                   8.4
# 9            2.4        4.0          AM8         Z                  10.0
# 10           2.4        4.0          AM8         Z                  10.2
# 11           3.5        6.0          AS9         Z                  11.4
# 12           3.5        6.0          AS9         Z                  12.0
# 13           1.8        4.0          AM6         Z                   9.7
# 14           1.8        4.0          AM6         Z                   9.7
# 15           2.0        4.0           A8         Z                  10.0
# 16           2.0        4.0           A8         Z                  10.5
# 17           2.9        6.0           A8         Z                  13.8
# 18           2.0        4.0           A8         Z                  10.3
# 19           2.0        4.0           A8         Z                  10.8
# 20           2.9        6.0           A8         Z                  14.1
# 21           4.0        8.0           A8         Z                  13.0
# 22           5.2       12.0           A8         Z                  15.5
# 23           5.2       12.0           A8         Z                  16.4
# 24           6.0       12.0           A8         Z                  16.7
# 25           6.0       12.0           A8         Z                  17.5
# 26           4.0        8.0           A8         Z                  12.7
# 27           2.0        4.0          AM7         X                   9.1
# 28           2.0        4.0          AM7         X                  10.9
# 29           2.0        4.0          AM7         X                  10.7
# ...          ...        ...          ...       ...                   ...
# 993          2.0        4.0           M6         X                   9.8
# 994          2.0        4.0          AM7         Z                  10.2
# 995          2.0        4.0           M6         Z                  11.4
# 996          1.8        4.0          AM6         X                  10.7
# 997          1.8        4.0           M6         X                  11.1
# 998          1.4        4.0          AS8         X                   8.6
# 999          1.4        4.0           M6         X                   8.2
# 1000         1.8        4.0          AM6         X                  10.8
# 1001         1.8        4.0           M6         X                  10.8
# 1002         1.4        4.0          AM8         X                   7.8
# 1003         1.4        4.0           M6         X                   7.9
# 1004         2.0        4.0          AM7         X                   9.3
# 1005         2.0        4.0           M6         X                   9.6
# 1006         2.0        4.0          AS6         X                   9.3
# 1007         2.0        4.0          AS8         X                  10.7
# 1008         2.0        4.0          AS8         X                  11.1
# 1009         2.0        4.0          AS8         Z                   9.9
# 1010         2.0        4.0          AS8         Z                  11.1
# 1011         2.0        4.0          AS8         Z                  10.6
# 1012         2.0        4.0          AS8         Z                  11.1
# 1013         2.0        4.0          AS8         Z                   9.9
# 1014         2.0        4.0          AS8         Z                  11.1
# 1015         2.0        4.0          AS8         Z                  10.8
# 1016         2.0        4.0          AS8         Z                  11.1
# 1017         2.0        4.0          AS8         Z                  11.6
# 1018         2.0        4.0          AS8         Z                  10.3
# 1019         2.0        4.0          AS8         Z                  11.3
# 1020         2.0        4.0          AS8         Z                  11.8
# 1021         2.0        4.0          AS8         Z                  11.3
# 1022         2.0        4.0          AS8         Z                  12.1
#
#      Fuel Consumption Hwy Fuel Consumption Comb  Comb (mpg) CO2 Emissions  \
# 0          Hwy (L/100 km)       Comb (L/100 km)  Comb (mpg)        (g/km)
# 1                     7.0                   8.6          33           199
# 2                     9.0                  10.8          26           252
# 3                     9.5                  11.0          26           258
# 4                     9.0                   9.0          31           210
# 5                    10.8                  11.0          26           261
# 6                     8.6                   9.9          29           232
# 7                     9.1                  10.3          27           242
# 8                     8.2                   8.4          34           196
# 9                     7.1                   8.7          32           205
# 10                    7.4                   8.9          32           209
# 11                    7.7                   9.8          29           228
# 12                    8.2                  10.3          27           240
# 13                    6.9                   8.4          34           197
# 14                    6.9                   8.4          34           197
# 15                    7.2                   8.7          32           205
# 16                    7.7                   9.2          31           217
# 17                    9.6                  11.9          24           280
# 18                    8.1                   9.3          30           218
# 19                    8.3                   9.6          29           226
# 20                   10.4                  12.4          23           292
# 21                    9.8                  11.5          25           271
# 22                   10.6                  13.3          21           312
# 23                   10.7                  13.8          20           324
# 24                   10.9                  14.1          20           332
# 25                   11.4                  14.7          19           346
# 26                    9.4                  11.2          25           264
# 27                    6.8                   8.1          35           188
# 28                    7.9                   9.6          29           225
# 29                    7.9                   9.5          30           221
# ...                   ...                   ...         ...           ...
# 993                   7.3                   8.7          32           203
# 994                   7.9                   9.2          31           213
# 995                   8.2                   9.9          29           232
# 996                   8.0                   9.4          30           220
# 997                   7.8                   9.6          29           225
# 998                   6.5                   7.6          37           178
# 999                   6.3                   7.4          38           172
# 1000                  8.1                   9.6          29           224
# 1001                  7.6                   9.3          30           218
# 1002                  5.9                   7.0          40           163
# 1003                  5.9                   7.0          40           163
# 1004                  7.2                   8.4          34           196
# 1005                  7.3                   8.5          33           200
# 1006                  6.5                   8.1          35           188
# 1007                  8.0                   9.5          30           221
# 1008                  8.1                   9.8          29           228
# 1009                  6.6                   8.4          34           197
# 1010                  7.3                   9.4          30           218
# 1011                  7.4                   9.2          31           215
# 1012                  7.3                   9.4          30           219
# 1013                  6.6                   8.4          34           197
# 1014                  7.3                   9.4          30           219
# 1015                  7.6                   9.3          30           218
# 1016                  7.3                   9.4          30           219
# 1017                  8.1                  10.0          28           233
# 1018                  7.5                   9.0          31           211
# 1019                  8.5                  10.0          28           233
# 1020                  8.6                  10.4          27           242
# 1021                  8.5                  10.0          28           233
# 1022                  8.9                  10.7          26           250
#
#      CO2 Rating Smog Rating
# 0        Rating      Rating
# 1             6           3
# 2             4           3
# 3             4           3
# 4             5           3
# 5             4           3
# 6             5           6
# 7             5           6
# 8             6           7
# 9             6           3
# 10            5           3
# 11            5           3
# 12            5           3
# 13            6           1
# 14            6           1
# 15            6           3
# 16            5           3
# 17            4           3
# 18            5           3
# 19            5           3
# 20            3           3
# 21            4           3
# 22            3           3
# 23            3           3
# 24            3           3
# 25            2           3
# 26            4           3
# 27            6           7
# 28            5           7
# 29            5           7
# ...         ...         ...
# 993           6           7
# 994           5           3
# 995           5           3
# 996           5           7
# 997           5           7
# 998           7           7
# 999           7           7
# 1000          5           7
# 1001          5           7
# 1002          8           7
# 1003          8           7
# 1004          6           7
# 1005          6           7
# 1006          6           7
# 1007          5           7
# 1008          5           7
# 1009          6           5
# 1010          5           7
# 1011          5           5
# 1012          5           7
# 1013          6           5
# 1014          5           7
# 1015          5           5
# 1016          5           7
# 1017          5           7
# 1018          5           5
# 1019          5           5
# 1020          5           7
# 1021          5           5
# 1022          4           7
#
# [1023 rows x 15 columns]

# %%
def drop_extra_rows(data):
    return data.drop(0).dropna(thresh=5) # Drop any row which don't have at least 5 non-NA values

data = drop_extra_rows(data)

# %%
data.head()
# Out:
#    Year   Make              Model       Class Engine Size  Cylinders  \
# 1  2019  Acura                ILX     Compact         2.4        4.0
# 2  2019  Acura         MDX SH-AWD  SUV: Small         3.5        6.0
# 3  2019  Acura  MDX SH-AWD A-SPEC  SUV: Small         3.5        6.0
# 4  2019  Acura     MDX Hybrid AWD  SUV: Small         3.0        6.0
# 5  2019  Acura                NSX  Two-seater         3.5        6.0
#
#   Transmission Fuel Type Fuel Consumption City Fuel Consumption Hwy  \
# 1          AM8         Z                   9.9                  7.0
# 2          AS9         Z                  12.2                  9.0
# 3          AS9         Z                  12.2                  9.5
# 4          AM7         Z                   9.1                  9.0
# 5          AM9         Z                  11.1                 10.8
#
#   Fuel Consumption Comb Comb (mpg) CO2 Emissions CO2 Rating Smog Rating
# 1                   8.6         33           199          6           3
# 2                  10.8         26           252          4           3
# 3                  11.0         26           258          4           3
# 4                   9.0         31           210          5           3
# 5                  11.0         26           261          4           3

# %% [markdown]
# ### Convert Data Types
# Because of the extra rows, Pandas interpreted most of the numeric columns as `object`, it's most generic data type, so we need to convert them so we can use them as numbers.

# %%
data.describe()
# Out:
#          Cylinders
# count  1022.000000
# mean      5.588063
# std       1.800961
# min       3.000000
# 25%       4.000000
# 50%       6.000000
# 75%       6.000000
# max      16.000000

# %%
data.dtypes
# Out:
# Year                      object
# Make                      object
# Model                     object
# Class                     object
# Engine Size               object
# Cylinders                float64
# Transmission              object
# Fuel Type                 object
# Fuel Consumption City     object
# Fuel Consumption Hwy      object
# Fuel Consumption Comb     object
# Comb (mpg)                object
# CO2 Emissions             object
# CO2 Rating                object
# Smog Rating               object
# dtype: object

# %% [markdown]
# This attempts to convert all columns to numeric data types, ignoring those that can't be converted. An alternative for more control is to use `astype`.

# %%
data = data.apply(pd.to_numeric, errors='ignore')
data.dtypes
# Out:
# Year                       int64
# Make                      object
# Model                     object
# Class                     object
# Engine Size              float64
# Cylinders                float64
# Transmission              object
# Fuel Type                 object
# Fuel Consumption City    float64
# Fuel Consumption Hwy     float64
# Fuel Consumption Comb    float64
# Comb (mpg)                 int64
# CO2 Emissions              int64
# CO2 Rating                 int64
# Smog Rating                int64
# dtype: object

# %% [markdown]
# All of the columns that are numbers are now being treated as numbers.

# %%
data.describe()
# Out:
#          Year  Engine Size    Cylinders  Fuel Consumption City  \
# count  1022.0  1022.000000  1022.000000            1022.000000
# mean   2019.0     3.110861     5.588063              12.363209
# std       0.0     1.320259     1.800961               3.306124
# min    2019.0     1.000000     3.000000               4.200000
# 25%    2019.0     2.000000     4.000000              10.200000
# 50%    2019.0     3.000000     6.000000              12.000000
# 75%    2019.0     3.600000     6.000000              14.300000
# max    2019.0     8.000000    16.000000              26.800000
#
#        Fuel Consumption Hwy  Fuel Consumption Comb   Comb (mpg)  \
# count            1022.00000            1022.000000  1022.000000
# mean                9.02319              10.857730    27.683953
# std                 2.05046               2.705248     7.355990
# min                 4.00000               4.100000    13.000000
# 25%                 7.60000               9.100000    23.000000
# 50%                 8.70000              10.600000    27.000000
# 75%                10.20000              12.500000    31.000000
# max                17.20000              22.200000    69.000000
#
#        CO2 Emissions   CO2 Rating  Smog Rating
# count    1022.000000  1022.000000  1022.000000
# mean      250.762231     4.575342     4.144814
# std        57.054017     1.656524     1.782098
# min        96.000000     1.000000     1.000000
# 25%       211.250000     3.000000     3.000000
# 50%       247.500000     4.000000     5.000000
# 75%       289.000000     5.000000     5.000000
# max       522.000000    10.000000     7.000000

# %% [markdown]
# ## Putting it all together to look at more years

# %%
def clean_data(df):
    df = drop_empty_columns(df)
    columns = ['Year', 'Make', 'Model', 'Class', 'Engine Size',
        'Cylinders', 'Transmission', 'Fuel Type',
        'Fuel Consumption City', 'Fuel Consumption Hwy', 'Fuel Consumption Comb',
        'Comb (mpg)', 'CO2 Emissions', 'CO2 Rating', 'Smog Rating']
    data.columns = columns
    df = drop_extra_rows(df)
    df = df.apply(pd.to_numeric, errors='ignore')
    return df

# %%
my2000 = pd.read_csv("downloads/MY2000 Fuel Consumption Ratings 5-cycle.csv")
my2000.head()
# Out:
#   MODEL   MAKE                 MODEL.1 VEHICLE CLASS ENGINE SIZE  CYLINDERS  \
# 0  YEAR    NaN  # = high output engine           NaN         (L)        NaN
# 1  2000  ACURA                   1.6EL       COMPACT         1.6        4.0
# 2  2000  ACURA                   1.6EL       COMPACT         1.6        4.0
# 3  2000  ACURA                   3.2TL      MID-SIZE         3.2        6.0
# 4  2000  ACURA                   3.5RL      MID-SIZE         3.5        6.0
#
#   TRANSMISSION  FUEL FUEL CONSUMPTION*      Unnamed: 9      Unnamed: 10  \
# 0          NaN  TYPE   CITY (L/100 km)  HWY (L/100 km)  COMB (L/100 km)
# 1           A4     X              10.5               8              9.4
# 2           M5     X               9.8             7.8              8.9
# 3          AS5     Z              13.7             8.8             11.5
# 4           A4     Z                15            10.9             13.1
#
#   Unnamed: 11 CO2 EMISSIONS
# 0  COMB (mpg)         (g/km)
# 1          30            216
# 2          32            205
# 3          25            265
# 4          22            301

# %%
my2000 = clean_data(my2000)
my2000.tail()
# Out:
#      MODEL   MAKE         MODEL.1             VEHICLE CLASS  ENGINE SIZE  \
# 635   2000  VOLVO   V70 AWD TURBO  STATION WAGON - MID-SIZE          2.4
# 636   2000  VOLVO   V70 GLT TURBO  STATION WAGON - MID-SIZE          2.4
# 637   2000  VOLVO    V70 T5 TURBO  STATION WAGON - MID-SIZE          2.3
# 638   2000  VOLVO    V70 T5 TURBO  STATION WAGON - MID-SIZE          2.3
# 639   2000  VOLVO  V70R AWD TURBO  STATION WAGON - MID-SIZE          2.4
#
#      CYLINDERS TRANSMISSION FUEL  FUEL CONSUMPTION*  Unnamed: 9  Unnamed: 10  \
# 635        5.0           A4    Z               14.4        10.3         12.5
# 636        5.0           A4    Z               13.6         9.7         11.9
# 637        5.0           A4    Z               13.9         9.5         11.9
# 638        5.0           M5    Z               13.0         9.3         11.3
# 639        5.0           A5    Z               14.7        10.9         13.0
#
#      Unnamed: 11  CO2 EMISSIONS
# 635           23             288
# 636           24             274
# 637           24             274
# 638           25             260
# 639           22             299

# %%
my2000.head()
# Out:
#    MODEL   MAKE  MODEL.1 VEHICLE CLASS  ENGINE SIZE  CYLINDERS TRANSMISSION  \
# 1   2000  ACURA    1.6EL       COMPACT          1.6        4.0           A4
# 2   2000  ACURA    1.6EL       COMPACT          1.6        4.0           M5
# 3   2000  ACURA    3.2TL      MID-SIZE          3.2        6.0          AS5
# 4   2000  ACURA    3.5RL      MID-SIZE          3.5        6.0           A4
# 5   2000  ACURA  INTEGRA    SUBCOMPACT          1.8        4.0           A4
#
#   FUEL  FUEL CONSUMPTION*  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 1    X               10.5         8.0          9.4           30
# 2    X                9.8         7.8          8.9           32
# 3    Z               13.7         8.8         11.5           25
# 4    Z               15.0        10.9         13.1           22
# 5    X               11.4         8.3         10.0           28
#
#    CO2 EMISSIONS
# 1             216
# 2             205
# 3             265
# 4             301
# 5             230

# %%
my2000.columns, data.columns
# Out:
# (Index(['MODEL', 'MAKE', 'MODEL.1', 'VEHICLE CLASS', 'ENGINE SIZE', 'CYLINDERS',
#         'TRANSMISSION', 'FUEL', 'FUEL CONSUMPTION*', 'Unnamed: 9',
#         'Unnamed: 10', 'Unnamed: 11', 'CO2 EMISSIONS '],
#        dtype='object'),
#  Index(['Year', 'Make', 'Model', 'Class', 'Engine Size', 'Cylinders',
#         'Transmission', 'Fuel Type', 'Fuel Consumption City',
#         'Fuel Consumption Hwy', 'Fuel Consumption Comb', 'Comb (mpg)',
#         'CO2 Emissions', 'CO2 Rating', 'Smog Rating'],
#        dtype='object'))

# %% [markdown]
# ### Problem: Columns have changed over time
# It looks like there are 2 columns for CO2 and Smog ratings that were added in more recent years. This isn't too bad because it's just a couple columns at the end; if the columns were changing around a lot every year it could get complicated.

# %%
# Update column names
def set_columns(data, columns):
    if len(data.columns) < len(columns):
        diff = len(data.columns) - len(columns)
        data.columns = columns[:diff]
        # Add missing columns
        for i in range(diff, 0):
            data[columns[i]] = np.nan
    else:
        data.columns = columns
        
    
    
    return data

def clean_data(df):
    columns = ['Year', 'Make', 'Model', 'Class', 'Engine Size',
        'Cylinders', 'Transmission', 'Fuel Type',
        'Fuel Consumption City', 'Fuel Consumption Hwy', 'Fuel Consumption Comb',
        'Comb (mpg)', 'CO2 Emissions', 'CO2 Rating', 'Smog Rating']

    df = drop_empty_columns(df)
    df = set_columns(df, columns)
    df = drop_extra_rows(df)
    df = df.apply(pd.to_numeric, errors='ignore')
    return df

# %% [markdown]
# ## Putting it all together!

# %%
def load_and_clean_emissions_files(files):
    data_frames = []
    for f in en_consumption_files:
        df = pd.read_csv(f)
        df = clean_data(df)
        data_frames.append(df)

    return pd.concat(data_frames, ignore_index=True)
combined = load_and_clean_emissions_files(en_consumption_files)
combined.describe()
# Out:
#                Year   Engine Size     Cylinders  Fuel Consumption City  \
# count  19739.000000  19739.000000  19739.000000           19739.000000
# mean    2010.174173      3.378662      5.875019              13.928046
# std        5.504800      1.328046      1.798473               3.777631
# min     2000.000000      0.800000      2.000000               4.200000
# 25%     2006.000000      2.400000      4.000000              11.400000
# 50%     2010.000000      3.200000      6.000000              13.400000
# 75%     2015.000000      4.300000      8.000000              16.000000
# max     2019.000000      8.400000     16.000000              33.300000
#
#        Fuel Consumption Hwy  Fuel Consumption Comb    Comb (mpg)  \
# count          19739.000000           19739.000000  19739.000000
# mean              10.015305              12.167491     24.830994
# std                2.620650               3.223160      6.641799
# min                4.000000               4.100000     10.000000
# 25%                8.200000              10.000000     20.000000
# 50%                9.500000              11.600000     24.000000
# 75%               11.400000              13.900000     28.000000
# max               22.100000              27.500000     69.000000
#
#        CO2 Emissions   CO2 Rating  Smog Rating
# count   19739.000000  4263.000000  3161.000000
# mean      274.624246     4.805067     4.652325
# std        64.448530     1.643140     1.837626
# min        96.000000     1.000000     1.000000
# 25%       230.000000     4.000000     3.000000
# 50%       267.000000     5.000000     5.000000
# 75%       313.000000     6.000000     6.000000
# max       633.000000    10.000000     8.000000

# %%
combined.groupby('Year')["Fuel Consumption Comb"].mean().plot()

# %% [markdown]
# And now I want to do all that again but using the French data files - maybe to compare that they're the same. Now that it's all set up, it's easy!

# %%
fr_consumption_files = download_files("AM[0-9]{4} Cotes de consommation de carburant.*csv")
# Out:
# Datasets provide model-specific fuel consumption ratings and estimated carbon dioxide emissions for new light-duty vehicles for retail sale in Canada.
#
# To help you compare vehicles from different model years, the fuel consumption ratings for 1995 to 2014 vehicles have been adjusted to reflect the improved testing that is more representative of everyday driving. Note that these are approximate values that were generated from the original ratings, not from vehicle testing.
#
# For more information on fuel consumption testing, visit: https://www.nrcan.gc.ca/energy/efficiency/transportation/21008.
#
# To compare the fuel consumption information of 1995 to 2019 model year vehicles, use the fuel consumption ratings search tool at https://fcr-ccc.nrcan-rncan.gc.ca/en.
#
# (Data update: June 27, 2019)
#
# Downloading 2000 Fuel Consumption Ratings from https://www.rncan.gc.ca/sites/www.rncan.gc.ca/files/oee/files/csv/AM2000%20Cotes%20de%20consommation%20de%20carburant%20cinq%20cycles.csv
# Downloading 2001 Fuel Consumption Ratings from https://www.rncan.gc.ca/sites/www.rncan.gc.ca/files/oee/files/csv/AM2001%20Cotes%20de%20consommation%20de%20carburant%20cinq%20cycles.csv
# Downloading 2002 Fuel Consumption Ratings from https://www.rncan.gc.ca/sites/www.rncan.gc.ca/files/oee/files/csv/AM2002%20Cotes%20de%20consommation%20de%20carburant%20cinq%20cycles.csv
# Downloading 2003 Fuel Consumption Ratings from https://www.rncan.gc.ca/sites/www.rncan.gc.ca/files/oee/files/csv/AM2003%20Cotes%20de%20consommation%20de%20carburant%20cinq%20cycles.csv
# Downloading 2004 Fuel Consumption Ratings from https://www.rncan.gc.ca/sites/www.rncan.gc.ca/files/oee/files/csv/AM2004%20Cotes%20de%20consommation%20de%20carburant%20cinq%20cycles.csv
# Downloading 2005 Fuel Consumption Ratings from https://www.rncan.gc.ca/sites/www.rncan.gc.ca/files/oee/files/csv/AM2005%20Cotes%20de%20consommation%20de%20carburant%20cinq%20cycles.csv
# Downloading 2006 Fuel Consumption Ratings from https://www.rncan.gc.ca/sites/www.rncan.gc.ca/files/oee/files/csv/AM2006%20Cotes%20de%20consommation%20de%20carburant%20cinq%20cycles.csv
# Downloading 2007 Fuel Consumption Ratings from https://www.rncan.gc.ca/sites/www.rncan.gc.ca/files/oee/files/csv/AM2007%20Cotes%20de%20consommation%20de%20carburant%20cinq%20cycles.csv
# Downloading 2008 Fuel Consumption Ratings from https://www.rncan.gc.ca/sites/www.rncan.gc.ca/files/oee/files/csv/AM2008%20Cotes%20de%20consommation%20de%20carburant%20cinq%20cycles.csv
# Downloading 2009 Fuel Consumption Ratings from https://www.rncan.gc.ca/sites/www.rncan.gc.ca/files/oee/files/csv/AM2009%20Cotes%20de%20consommation%20de%20carburant%20cinq%20cycles.csv
# Downloading 2010 Fuel Consumption Ratings from https://www.rncan.gc.ca/sites/www.rncan.gc.ca/files/oee/files/csv/AM2010%20Cotes%20de%20consommation%20de%20carburant%20cinq%20cycles.csv
# Downloading 2011 Fuel Consumption Ratings from https://www.rncan.gc.ca/sites/www.rncan.gc.ca/files/oee/files/csv/AM2011%20Cotes%20de%20consommation%20de%20carburant%20cinq%20cycles.csv
# Downloading 2012 Fuel Consumption Ratings from https://www.rncan.gc.ca/sites/www.rncan.gc.ca/files/oee/files/csv/AM2012%20Cotes%20de%20consommation%20de%20carburant%20cinq%20cycles.csv
# Downloading 2013 Fuel Consumption Ratings (2018-07-17) from https://www.rncan.gc.ca/sites/www.rncan.gc.ca/files/oee/files/csv/AM2013%20Cotes%20de%20consommation%20de%20carburant%20(cinq%20cycles).csv
# Downloading 2014 Fuel Consumption Ratings (2018-07-17) from https://www.rncan.gc.ca/sites/www.rncan.gc.ca/files/oee/files/csv/AM2014%20Cotes%20de%20consommation%20de%20carburant%20(cinq%20cycles).csv
# Downloading 2015 Fuel Consumption Ratings (2016-10-21) from https://www.rncan.gc.ca/sites/www.rncan.gc.ca/files/oee/files/csv/AM2015%20Cotes%20de%20consommation%20de%20carburant%20(cinq%20cycles).csv
# Downloading 2016 Fuel Consumption Ratings (2017-01-04) from https://www.rncan.gc.ca/sites/www.rncan.gc.ca/files/oee/files/csv/AM2016%20Cotes%20de%20consommation%20de%20carburant.csv
# Downloading 2017 Fuel Consumption Ratings (2018-07-17) from https://www.rncan.gc.ca/sites/www.nrcan.gc.ca/files/oee/files/csv/AM2017%20Cotes%20de%20consommation%20de%20carburant.csv
# Downloading 2018 Fuel Consumption Ratings (2019-01-29) from https://www.rncan.gc.ca/sites/www.nrcan.gc.ca/files/oee/files/csv/AM2018%20Cotes%20de%20consommation%20de%20carburant.csv
# Downloading 2019 Fuel Consumption Ratings (2019-05-14) from https://www.rncan.gc.ca/sites/www.nrcan.gc.ca/files/oee/files/csv/AM2019%20Cotes%20de%20consommation%20de%20carburant.csv

# %%
combined_fr =load_and_clean_emissions_files(fr_consumption_files)
# All of the numbers match!
combined_fr.mean() == combined.mean()
# Out:
# Year                     True
# Engine Size              True
# Cylinders                True
# Fuel Consumption City    True
# Fuel Consumption Hwy     True
# Fuel Consumption Comb    True
# Comb (mpg)               True
# CO2 Emissions            True
# CO2 Rating               True
# Smog Rating              True
# dtype: bool

# %% [markdown]
# ## There's often more than one way to do it
# Another way to deal with a two line header, or other scenarios where there is extra data at the start of a file, is to set the `names`, `skiprows`, and `header` options when reading in the file. Another similar option is `skipfooter` if you have a known number of footer lines to skip. However, with this dataset, we can't use the same code to handle both the varying numbers of columns and the extra junk columns easily on read.

# %%
# It will deal with too many columns just fine
newer_colnames = ['Year', 'Make', 'Model', 'Class', 'Engine Size',
        'Cylinders', 'Transmission', 'Fuel Type',
        'Fuel Consumption City', 'Fuel Consumption Hwy', 'Fuel Consumption Comb',
        'Comb (mpg)', 'CO2 Emissions', 'CO2 Rating', 'Smog Rating']
pd.read_csv('downloads/MY2000 Fuel Consumption Ratings 5-cycle.csv', names=newer_colnames, skiprows=3, header=None).head()
# Out:
#    Year   Make    Model       Class  Engine Size  Cylinders Transmission  \
# 0  2000  ACURA    1.6EL     COMPACT          1.6        4.0           A4
# 1  2000  ACURA    1.6EL     COMPACT          1.6        4.0           M5
# 2  2000  ACURA    3.2TL    MID-SIZE          3.2        6.0          AS5
# 3  2000  ACURA    3.5RL    MID-SIZE          3.5        6.0           A4
# 4  2000  ACURA  INTEGRA  SUBCOMPACT          1.8        4.0           A4
#
#   Fuel Type  Fuel Consumption City  Fuel Consumption Hwy  \
# 0         X                   10.5                   8.0
# 1         X                    9.8                   7.8
# 2         Z                   13.7                   8.8
# 3         Z                   15.0                  10.9
# 4         X                   11.4                   8.3
#
#    Fuel Consumption Comb  Comb (mpg)  CO2 Emissions  CO2 Rating  Smog Rating
# 0                    9.4        30.0          216.0         NaN          NaN
# 1                    8.9        32.0          205.0         NaN          NaN
# 2                   11.5        25.0          265.0         NaN          NaN
# 3                   13.1        22.0          301.0         NaN          NaN
# 4                   10.0        28.0          230.0         NaN          NaN

# %%
# But because of the extra blank columns in some of the files I also have to set usecols, but this throws an error if I use it on the older files
pd.read_csv('downloads/MY2019 Fuel Consumption Ratings.csv', names=newer_colnames, usecols=range(0, len(newer_colnames)), skiprows=3, header=None).head()
# Out:
#    Year   Make              Model       Class  Engine Size  Cylinders  \
# 0  2019  Acura                ILX     Compact          2.4        4.0
# 1  2019  Acura         MDX SH-AWD  SUV: Small          3.5        6.0
# 2  2019  Acura  MDX SH-AWD A-SPEC  SUV: Small          3.5        6.0
# 3  2019  Acura     MDX Hybrid AWD  SUV: Small          3.0        6.0
# 4  2019  Acura                NSX  Two-seater          3.5        6.0
#
#   Transmission Fuel Type  Fuel Consumption City  Fuel Consumption Hwy  \
# 0          AM8         Z                    9.9                   7.0
# 1          AS9         Z                   12.2                   9.0
# 2          AS9         Z                   12.2                   9.5
# 3          AM7         Z                    9.1                   9.0
# 4          AM9         Z                   11.1                  10.8
#
#    Fuel Consumption Comb  Comb (mpg)  CO2 Emissions  CO2 Rating  Smog Rating
# 0                    8.6        33.0          199.0         6.0          3.0
# 1                   10.8        26.0          252.0         4.0          3.0
# 2                   11.0        26.0          258.0         4.0          3.0
# 3                    9.0        31.0          210.0         5.0          3.0
# 4                   11.0        26.0          261.0         4.0          3.0

# %% [markdown]
# If our problem with column names was just that they were spread out over two rows, we could write some code to automatically merge them.

# %%
# Update column names
def merge_2_row_names(data):
    new_columns = []
    for i, c in enumerate(data.columns):
        new_name = ""
        first_row_val = data.iloc[0, i]
        
        if c.startswith("Unnamed"):
            new_name = first_row_val
        elif not isinstance(first_row_val, str):
            new_name = c
        else:
            new_name = c + " " + first_row_val
        new_columns.append(new_name)
    data.columns = new_columns
    
    return data.drop(0)


merge_2_row_names(pd.read_csv('downloads/MY2000 Fuel Consumption Ratings 5-cycle.csv'))
# Out:
#                                             MODEL YEAR  \
# 1                                                 2000
# 2                                                 2000
# 3                                                 2000
# 4                                                 2000
# 5                                                 2000
# 6                                                 2000
# 7                                                 2000
# 8                                                 2000
# 9                                                 2000
# 10                                                2000
# 11                                                2000
# 12                                                2000
# 13                                                2000
# 14                                                2000
# 15                                                2000
# 16                                                2000
# 17                                                2000
# 18                                                2000
# 19                                                2000
# 20                                                2000
# 21                                                2000
# 22                                                2000
# 23                                                2000
# 24                                                2000
# 25                                                2000
# 26                                                2000
# 27                                                2000
# 28                                                2000
# 29                                                2000
# 30                                                2000
# ..                                                 ...
# 635                                               2000
# 636                                               2000
# 637                                               2000
# 638                                               2000
# 639                                               2000
# 640                                                NaN
# 641  *Starting with the 2015 model year, vehicle ma...
# 642  more representative of everyday driving. To he...
# 643  generated from the original ratings, not from ...
# 644                                                NaN
# 645                            Understanding the Table
# 646                                              Model
# 647                                                NaN
# 648                                                NaN
# 649                                                NaN
# 650                                                NaN
# 651                                                NaN
# 652                                       Transmission
# 653                                                NaN
# 654                                                NaN
# 655                                                NaN
# 656                                                NaN
# 657                                                NaN
# 658                                          Fuel Type
# 659                                                NaN
# 660                                                NaN
# 661                                                NaN
# 662                                                NaN
# 663                                   Fuel Consumption
# 664                               CO2 Emissions (g/km)
#
#                                                   MAKE  \
# 1                                                ACURA
# 2                                                ACURA
# 3                                                ACURA
# 4                                                ACURA
# 5                                                ACURA
# 6                                                ACURA
# 7                                                ACURA
# 8                                                ACURA
# 9                                                ACURA
# 10                                                AUDI
# 11                                                AUDI
# 12                                                AUDI
# 13                                                AUDI
# 14                                                AUDI
# 15                                                AUDI
# 16                                                AUDI
# 17                                                AUDI
# 18                                                AUDI
# 19                                                AUDI
# 20                                                AUDI
# 21                                                AUDI
# 22                                                AUDI
# 23                                                AUDI
# 24                                                AUDI
# 25                                                AUDI
# 26                                                AUDI
# 27                                                AUDI
# 28                                                AUDI
# 29                                                AUDI
# 30                                                AUDI
# ..                                                 ...
# 635                                              VOLVO
# 636                                              VOLVO
# 637                                              VOLVO
# 638                                              VOLVO
# 639                                              VOLVO
# 640                                                NaN
# 641                                                NaN
# 642                                                NaN
# 643                                                NaN
# 644                                                NaN
# 645                                                NaN
# 646                         4WD/4X4 = Four-wheel drive
# 647                              AWD = All-wheel drive
# 648                       CNG = Compressed natural gas
# 649                        FFV = Flexible-fuel vehicle
# 650                          NGV = Natural gas vehicle
# 651  # = High output engine that provides more powe...
# 652                                      A = Automatic
# 653                              AM = Automated manual
# 654                   AS = Automatic with select shift
# 655                         AV = Continuously variable
# 656                                         M = Manual
# 657                           3  10 = Number of gears
# 658                               X = Regular gasoline
# 659                               Z = Premium gasoline
# 660                                         D = Diesel
# 661                                  E = Ethanol (E85)
# 662                                    N = Natural Gas
# 663  City and highway fuel consumption ratings are ...
# 664  Estimated tailpipe carbon dioxide emissions (i...
#
#       MODEL.1 # = high output engine             VEHICLE CLASS  \
# 1                              1.6EL                   COMPACT
# 2                              1.6EL                   COMPACT
# 3                              3.2TL                  MID-SIZE
# 4                              3.5RL                  MID-SIZE
# 5                            INTEGRA                SUBCOMPACT
# 6                            INTEGRA                SUBCOMPACT
# 7                 INTEGRA GSR/TYPE R                SUBCOMPACT
# 8                                NSX                SUBCOMPACT
# 9                                NSX                SUBCOMPACT
# 10                                A4                   COMPACT
# 11                                A4                   COMPACT
# 12                                A4                   COMPACT
# 13                                A4                   COMPACT
# 14                        A4 QUATTRO                   COMPACT
# 15                        A4 QUATTRO                   COMPACT
# 16                        A4 QUATTRO                   COMPACT
# 17                        A4 QUATTRO                   COMPACT
# 18                                A6                  MID-SIZE
# 19                  A6 AVANT QUATTRO  STATION WAGON - MID-SIZE
# 20                        A6 QUATTRO                  MID-SIZE
# 21                        A6 QUATTRO                  MID-SIZE
# 22                        A6 QUATTRO                  MID-SIZE
# 23                        A6 QUATTRO                  MID-SIZE
# 24                        A6 QUATTRO                  MID-SIZE
# 25                        A8 QUATTRO                  MID-SIZE
# 26                        S4 QUATTRO                   COMPACT
# 27                        S4 QUATTRO                   COMPACT
# 28                  TT COUPE QUATTRO               MINICOMPACT
# 29   TT COUPE QUATTRO (SUPERCHARGED)               MINICOMPACT
# 30                       TT ROADSTER                TWO-SEATER
# ..                               ...                       ...
# 635                    V70 AWD TURBO  STATION WAGON - MID-SIZE
# 636                    V70 GLT TURBO  STATION WAGON - MID-SIZE
# 637                     V70 T5 TURBO  STATION WAGON - MID-SIZE
# 638                     V70 T5 TURBO  STATION WAGON - MID-SIZE
# 639                   V70R AWD TURBO  STATION WAGON - MID-SIZE
# 640                              NaN                       NaN
# 641                              NaN                       NaN
# 642                              NaN                       NaN
# 643                              NaN                       NaN
# 644                              NaN                       NaN
# 645                              NaN                       NaN
# 646                              NaN                       NaN
# 647                              NaN                       NaN
# 648                              NaN                       NaN
# 649                              NaN                       NaN
# 650                              NaN                       NaN
# 651                              NaN                       NaN
# 652                              NaN                       NaN
# 653                              NaN                       NaN
# 654                              NaN                       NaN
# 655                              NaN                       NaN
# 656                              NaN                       NaN
# 657                              NaN                       NaN
# 658                              NaN                       NaN
# 659                              NaN                       NaN
# 660                              NaN                       NaN
# 661                              NaN                       NaN
# 662                              NaN                       NaN
# 663                              NaN                       NaN
# 664                              NaN                       NaN
#
#     ENGINE SIZE (L)  CYLINDERS TRANSMISSION FUEL TYPE  \
# 1               1.6        4.0           A4         X
# 2               1.6        4.0           M5         X
# 3               3.2        6.0          AS5         Z
# 4               3.5        6.0           A4         Z
# 5               1.8        4.0           A4         X
# 6               1.8        4.0           M5         X
# 7               1.8        4.0           M5         Z
# 8                 3        6.0          AS4         Z
# 9               3.2        6.0           M6         Z
# 10              1.8        4.0           A5         Z
# 11              1.8        4.0           M5         Z
# 12              2.8        6.0           A5         Z
# 13              2.8        6.0           M5         Z
# 14              1.8        4.0           A5         Z
# 15              1.8        4.0           M5         Z
# 16              2.8        6.0           A5         Z
# 17              2.8        6.0           M5         Z
# 18              2.8        6.0           A5         Z
# 19              2.8        6.0           A5         Z
# 20              2.7        6.0           A5         Z
# 21              2.7        6.0           M6         Z
# 22              2.8        6.0           A5         Z
# 23              2.8        6.0           M5         Z
# 24              4.2        8.0           A5         Z
# 25              4.2        8.0           A5         Z
# 26              2.7        6.0           A5         Z
# 27              2.7        6.0           M6         Z
# 28              1.8        4.0           M5         Z
# 29              1.8        4.0           M6         Z
# 30              1.8        4.0           M5         Z
# ..              ...        ...          ...       ...
# 635             2.4        5.0           A4         Z
# 636             2.4        5.0           A4         Z
# 637             2.3        5.0           A4         Z
# 638             2.3        5.0           M5         Z
# 639             2.4        5.0           A5         Z
# 640             NaN        NaN          NaN       NaN
# 641             NaN        NaN          NaN       NaN
# 642             NaN        NaN          NaN       NaN
# 643             NaN        NaN          NaN       NaN
# 644             NaN        NaN          NaN       NaN
# 645             NaN        NaN          NaN       NaN
# 646             NaN        NaN          NaN       NaN
# 647             NaN        NaN          NaN       NaN
# 648             NaN        NaN          NaN       NaN
# 649             NaN        NaN          NaN       NaN
# 650             NaN        NaN          NaN       NaN
# 651             NaN        NaN          NaN       NaN
# 652             NaN        NaN          NaN       NaN
# 653             NaN        NaN          NaN       NaN
# 654             NaN        NaN          NaN       NaN
# 655             NaN        NaN          NaN       NaN
# 656             NaN        NaN          NaN       NaN
# 657             NaN        NaN          NaN       NaN
# 658             NaN        NaN          NaN       NaN
# 659             NaN        NaN          NaN       NaN
# 660             NaN        NaN          NaN       NaN
# 661             NaN        NaN          NaN       NaN
# 662             NaN        NaN          NaN       NaN
# 663             NaN        NaN          NaN       NaN
# 664             NaN        NaN          NaN       NaN
#
#     FUEL CONSUMPTION* CITY (L/100 km) HWY (L/100 km) COMB (L/100 km)  \
# 1                                10.5              8             9.4
# 2                                 9.8            7.8             8.9
# 3                                13.7            8.8            11.5
# 4                                  15           10.9            13.1
# 5                                11.4            8.3              10
# 6                                10.6            8.1             9.5
# 7                                10.8            8.3             9.7
# 8                                15.2           10.9            13.3
# 9                                15.4           10.7            13.3
# 10                               12.9            8.6            10.9
# 11                               11.1            8.1             9.7
# 12                               14.6            9.7            12.4
# 13                               13.2            8.9            11.3
# 14                               13.6            9.1            11.6
# 15                               12.1            8.9            10.7
# 16                               14.9           10.1            12.7
# 17                               14.3           10.3            12.5
# 18                                 15           10.2            12.8
# 19                               15.4           10.7            13.3
# 20                               15.2           10.6            13.2
# 21                               15.2           10.7            13.2
# 22                               15.4           10.7            13.3
# 23                               14.6           10.9            12.9
# 24                               15.5           10.7            13.4
# 25                               15.5           10.7            13.4
# 26                               15.2           10.6            13.2
# 27                               15.2           10.7            13.2
# 28                               13.1              9            11.3
# 29                               13.1            9.1            11.3
# 30                               12.3            8.7            10.7
# ..                                ...            ...             ...
# 635                              14.4           10.3            12.5
# 636                              13.6            9.7            11.9
# 637                              13.9            9.5            11.9
# 638                                13            9.3            11.3
# 639                              14.7           10.9              13
# 640                               NaN            NaN             NaN
# 641                               NaN            NaN             NaN
# 642                               NaN            NaN             NaN
# 643                               NaN            NaN             NaN
# 644                               NaN            NaN             NaN
# 645                               NaN            NaN             NaN
# 646                               NaN            NaN             NaN
# 647                               NaN            NaN             NaN
# 648                               NaN            NaN             NaN
# 649                               NaN            NaN             NaN
# 650                               NaN            NaN             NaN
# 651                               NaN            NaN             NaN
# 652                               NaN            NaN             NaN
# 653                               NaN            NaN             NaN
# 654                               NaN            NaN             NaN
# 655                               NaN            NaN             NaN
# 656                               NaN            NaN             NaN
# 657                               NaN            NaN             NaN
# 658                               NaN            NaN             NaN
# 659                               NaN            NaN             NaN
# 660                               NaN            NaN             NaN
# 661                               NaN            NaN             NaN
# 662                               NaN            NaN             NaN
# 663                               NaN            NaN             NaN
# 664                               NaN            NaN             NaN
#
#     COMB (mpg) CO2 EMISSIONS  (g/km)
# 1           30                   216
# 2           32                   205
# 3           25                   265
# 4           22                   301
# 5           28                   230
# 6           30                   219
# 7           29                   223
# 8           21                   306
# 9           21                   306
# 10          26                   251
# 11          29                   223
# 12          23                   285
# 13          25                   260
# 14          24                   267
# 15          26                   246
# 16          22                   292
# 17          23                   288
# 18          22                   294
# 19          21                   306
# 20          21                   304
# 21          21                   304
# 22          21                   306
# 23          22                   297
# 24          21                   308
# 25          21                   308
# 26          21                   304
# 27          21                   304
# 28          25                   260
# 29          25                   260
# 30          26                   246
# ..         ...                   ...
# 635         23                   288
# 636         24                   274
# 637         24                   274
# 638         25                   260
# 639         22                   299
# 640        NaN                   NaN
# 641        NaN                   NaN
# 642        NaN                   NaN
# 643        NaN                   NaN
# 644        NaN                   NaN
# 645        NaN                   NaN
# 646        NaN                   NaN
# 647        NaN                   NaN
# 648        NaN                   NaN
# 649        NaN                   NaN
# 650        NaN                   NaN
# 651        NaN                   NaN
# 652        NaN                   NaN
# 653        NaN                   NaN
# 654        NaN                   NaN
# 655        NaN                   NaN
# 656        NaN                   NaN
# 657        NaN                   NaN
# 658        NaN                   NaN
# 659        NaN                   NaN
# 660        NaN                   NaN
# 661        NaN                   NaN
# 662        NaN                   NaN
# 663        NaN                   NaN
# 664        NaN                   NaN
#
# [664 rows x 13 columns]
